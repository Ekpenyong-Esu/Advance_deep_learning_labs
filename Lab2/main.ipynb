# %%
#Section                   Task                               
 #0  Setup            Environment and  wandb                
 #1  Vanilla GAN      Your current implementation        
 #2  Improvements     Fix stability (loss, architecture) 
 #3  Conditional GAN  Add label conditioning             
 #4  Evaluation       Generated digit quality            
 #5  Comparison       Vanilla vs cGAN                    
 #6  W&B              Logs

# %%
import sys
import os

project_root = os.path.dirname(os.path.abspath("__file__"))
sys.path.insert(0, project_root)

import torch
import config

print("=" * 55)
print(f"PyTorch version : {torch.__version__}")
print(f"CUDA available  : {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU             : {torch.cuda.get_device_name(0)}")
print(f"Device in use   : {config.DEVICE}")
print("=" * 55)
print()
# Out:
# ...
# PyTorch version : 2.11.0+cu130
# CUDA available  : True
# GPU             : NVIDIA GeForce RTX 2080 Ti
# Device in use   : cuda
# ...

# %%
import subprocess, sys

import wandb
wandb.login()   # prompts for API key if not already stored

print()
print("Logged in to wandb.")
print("After running experiments, view all results at: https://wandb.ai")
print(f"Project name: {__import__('config').WANDB_PROJECT}")
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: deeplab15group (deeplab15group-lule-university-of-technology) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Logged in to wandb.
# After running experiments, view all results at: https://wandb.ai
# Project name: gan-mnist

# %%
import GAN_task1

GAN_task1.run_training(use_logistic_loss=False) #BCE + sigmoid
# Out:
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/Labs/Lab2/wandb/run-20260416_200508-07iazx8f</code>
# Syncing run <strong><a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab2/runs/07iazx8f' target="_blank">efficient-snowball-1</a></strong> to <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab2' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab2' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab2</a>
#  View run at <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab2/runs/07iazx8f' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab2/runs/07iazx8f</a>
# ...

# %%
import GAN_task1

GAN_task1.run_training(use_logistic_loss=True) #Logistic loss
# Out:
# Finishing previous runs because reinit is set to 'default'.
# ...

# %%
import CGAN_task3

CGAN_task3.train()
# Out:
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 8.35MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 241kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 2.21MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 6.26MB/s]
# 100%|██████████| 938/938 [00:12<00:00, 74.31it/s]
# Epoch 0: D_loss=0.0447, G_loss=5.7912
# 100%|██████████| 938/938 [00:12<00:00, 76.29it/s]
# Epoch 1: D_loss=0.0194, G_loss=5.8225
# 100%|██████████| 938/938 [00:12<00:00, 77.68it/s]
# Epoch 2: D_loss=0.0470, G_loss=5.9479
# 100%|██████████| 938/938 [00:12<00:00, 75.89it/s]
# Epoch 3: D_loss=0.0646, G_loss=6.1036
# 100%|██████████| 938/938 [00:12<00:00, 77.42it/s]
# Epoch 4: D_loss=0.0951, G_loss=4.3810
# 100%|██████████| 938/938 [00:10<00:00, 88.65it/s]
# Epoch 5: D_loss=0.4160, G_loss=4.1400
# 100%|██████████| 938/938 [00:11<00:00, 78.41it/s]
# Epoch 6: D_loss=0.7123, G_loss=3.6347
# 100%|██████████| 938/938 [00:12<00:00, 73.79it/s]
# Epoch 7: D_loss=0.6811, G_loss=2.3524
# ...

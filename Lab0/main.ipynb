# %% [markdown]
# # Advanced AI Lab — Main Notebook
#
# This is the **single entry point** for all lab experiments.
# Run the cells top-to-bottom in each section you need.
# All heavy logic lives in the project files — this notebook just calls them.
#
# | Section | Task |
# |---|---|
# | 0 — Setup | Check GPU, verify imports |
# | 1 — Task 0.1 | Simple CNN: SGD vs Adam vs Tanh |
# | 2 — Task 0.2.1 | AlexNet transfer learning on CIFAR-10 |
# | 3 — Task 0.2.2 | MNIST → SVHN transfer learning |
# | 4 — Grade 5 | ViT-B/16 + Swin Transformer on CIFAR-10 |
# | 5 — TensorBoard | Visualise all experiment results |

# %% [markdown]
# ---
# ## Section 0 — Setup
#
# Run this cell once before anything else.
# It checks that PyTorch is installed and shows whether a GPU is available.

# %%
import sys
import os

# Make sure the project root is on the Python path so all imports work
project_root = "/Labs/Lab0"
sys.path.insert(0, project_root)

import torch
import config

import wandb


print("=" * 50)
print(f"PyTorch version : {torch.__version__}")
print(f"CUDA available  : {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU name        : {torch.cuda.get_device_name(0)}")
print(f"Device in use   : {config.DEVICE}")
print("=" * 50)
print("\nAll project modules are ready.")
print("Run any section below to start an experiment.")
# Out:
# ==================================================
# PyTorch version : 2.11.0+cu130
# CUDA available  : True
# GPU name        : NVIDIA GeForce RTX 2080 Ti
# Device in use   : cuda
# ==================================================
#
# All project modules are ready.
# Run any section below to start an experiment.

# %% [markdown]
# ---
# ## Section 1 — Task 0.1: Simple CNN on CIFAR-10
#
# Three experiments with the **same CNN architecture**, changing only one thing at a time:
#
# | Cell | Optimiser | Activation | What we learn |
# |---|---|---|---|
# | 1.1 | SGD | LeakyReLU | Baseline |
# | 1.2 | **Adam** | LeakyReLU | Effect of a better optimiser |
# | 1.3 | Adam | **Tanh** | Effect of changing the activation function |
#
# After running all three, compare their training curves side-by-side in TensorBoard (Section 5).

# %%
wandb.login()

 # prompts for API key if not already stored
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: deeplab15group (deeplab15group-lule-university-of-technology) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# 1.1  SGD + LeakyReLU — baseline experiment
from experiments.task01_cnn_sgd_leakyrelu import main as run_sgd_leakyrelu
run_sgd_leakyrelu()
# Out:
# Device: cuda
# GPU   : NVIDIA GeForce RTX 2080 Ti
#
# Loading CIFAR-10 …
# /usr/local/lib/python3.11/dist-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# CIFAR-10 ready | train: 40,000 | val: 10,000 | test: 10,000 | image size: 32×32
#
# Building SimpleCNN (LeakyReLU) …
# Total parameters: 1,276,682
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/wandb/run-20260404_145505-6kknw33l</code>
# Syncing run <strong><a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/6kknw33l' target="_blank">Task01_CNN_SGD_LeakyReLU</a></strong> to <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0</a>
#  View run at <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/6kknw33l' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/6kknw33l</a>
# ══════════════════════════════════════════════════════════════
#   Experiment  : Task01_CNN_SGD_LeakyReLU
#   Device      : cuda  (NVIDIA GeForce RTX 2080 Ti)
#   Optimiser   : SGD  lr=0.0001
#   Epochs      : 200
#   Trainable   : 1,276,682 parameters
#   Split       : 70% train / 15% val / 15% test
#   W&B project : advanced-ai-lab-0  (view at https://wandb.ai)
# ══════════════════════════════════════════════════════════════
#   Epoch  1/200  |  Train  loss=2.2864  acc=13.6%  |  Val    loss=2.2411  acc=24.0%
#   Epoch  2/200  |  Train  loss=2.2098  acc=20.9%  |  Val    loss=2.1062  acc=27.2%
#   Epoch  3/200  |  Train  loss=2.0777  acc=24.8%  |  Val    loss=1.9604  acc=30.4%
#   Epoch  4/200  |  Train  loss=1.9754  acc=27.5%  |  Val    loss=1.8590  acc=34.6%
#   Epoch  5/200  |  Train  loss=1.8968  acc=30.4%  |  Val    loss=1.7848  acc=36.8%
#   Epoch  6/200  |  Train  loss=1.8320  acc=32.7%  |  Val    loss=1.7083  acc=39.0%
#   Epoch  7/200  |  Train  loss=1.7781  acc=34.3%  |  Val    loss=1.6451  acc=41.0%
#   Epoch  8/200  |  Train  loss=1.7261  acc=36.0%  |  Val    loss=1.5889  acc=42.8%
#   Epoch  9/200  |  Train  loss=1.6796  acc=37.4%  |  Val    loss=1.5393  acc=44.2%
#   Epoch 10/200  |  Train  loss=1.6403  acc=39.0%  |  Val    loss=1.4987  acc=45.8%
#   Epoch 11/200  |  Train  loss=1.6089  acc=40.0%  |  Val    loss=1.4625  acc=47.1%
#   Epoch 12/200  |  Train  loss=1.5837  acc=41.3%  |  Val    loss=1.4385  acc=47.5%
#   Epoch 13/200  |  Train  loss=1.5548  acc=42.3%  |  Val    loss=1.4096  acc=48.8%
#   Epoch 14/200  |  Train  loss=1.5466  acc=42.7%  |  Val    loss=1.3876  acc=49.7%
#   Epoch 15/200  |  Train  loss=1.5246  acc=43.5%  |  Val    loss=1.3673  acc=50.9%
#   Epoch 16/200  |  Train  loss=1.5041  acc=44.4%  |  Val    loss=1.3487  acc=51.3%
#   Epoch 17/200  |  Train  loss=1.4883  acc=45.0%  |  Val    loss=1.3286  acc=51.9%
#   Epoch 18/200  |  Train  loss=1.4756  acc=45.5%  |  Val    loss=1.3021  acc=53.0%
#   Epoch 19/200  |  Train  loss=1.4484  acc=46.6%  |  Val    loss=1.2811  acc=53.7%
#   Epoch 20/200  |  Train  loss=1.4384  acc=47.3%  |  Val    loss=1.2635  acc=54.1%
#   Epoch 21/200  |  Train  loss=1.4198  acc=47.7%  |  Val    loss=1.2467  acc=54.6%
#   Epoch 22/200  |  Train  loss=1.4030  acc=48.6%  |  Val    loss=1.2359  acc=55.2%
#   Epoch 23/200  |  Train  loss=1.3870  acc=49.2%  |  Val    loss=1.2209  acc=56.0%
#   Epoch 24/200  |  Train  loss=1.3728  acc=49.5%  |  Val    loss=1.2108  acc=56.4%
#   Epoch 25/200  |  Train  loss=1.3553  acc=50.2%  |  Val    loss=1.1875  acc=57.1%
#   Epoch 26/200  |  Train  loss=1.3430  acc=51.0%  |  Val    loss=1.1757  acc=57.6%
#   Epoch 27/200  |  Train  loss=1.3329  acc=51.1%  |  Val    loss=1.1602  acc=57.9%
#   Epoch 28/200  |  Train  loss=1.3190  acc=51.9%  |  Val    loss=1.1651  acc=58.1%
#   Epoch 29/200  |  Train  loss=1.3031  acc=52.7%  |  Val    loss=1.1476  acc=58.6%
#   Epoch 30/200  |  Train  loss=1.2924  acc=52.9%  |  Val    loss=1.1279  acc=59.3%
#   Epoch 31/200  |  Train  loss=1.2880  acc=53.0%  |  Val    loss=1.1214  acc=59.8%
#   Epoch 32/200  |  Train  loss=1.2797  acc=53.5%  |  Val    loss=1.1073  acc=60.0%
#   Epoch 33/200  |  Train  loss=1.2663  acc=54.1%  |  Val    loss=1.1041  acc=60.5%
#   Epoch 34/200  |  Train  loss=1.2508  acc=54.6%  |  Val    loss=1.0795  acc=60.9%
#   Epoch 35/200  |  Train  loss=1.2476  acc=54.7%  |  Val    loss=1.0760  acc=61.1%
#   Epoch 36/200  |  Train  loss=1.2411  acc=55.1%  |  Val    loss=1.0735  acc=61.2%
#   Epoch 37/200  |  Train  loss=1.2322  acc=55.5%  |  Val    loss=1.0677  acc=61.4%
#   Epoch 38/200  |  Train  loss=1.2226  acc=55.8%  |  Val    loss=1.0470  acc=62.2%
#   Epoch 39/200  |  Train  loss=1.2104  acc=56.1%  |  Val    loss=1.0419  acc=62.3%
#   Epoch 40/200  |  Train  loss=1.2050  acc=56.5%  |  Val    loss=1.0374  acc=62.5%
#   Epoch 41/200  |  Train  loss=1.2009  acc=56.9%  |  Val    loss=1.0325  acc=62.4%
#   Epoch 42/200  |  Train  loss=1.1882  acc=56.9%  |  Val    loss=1.0266  acc=62.7%
#   Epoch 43/200  |  Train  loss=1.1836  acc=57.1%  |  Val    loss=1.0082  acc=63.3%
#   Epoch 44/200  |  Train  loss=1.1722  acc=57.6%  |  Val    loss=1.0031  acc=63.8%
#   Epoch 45/200  |  Train  loss=1.1632  acc=57.9%  |  Val    loss=1.0090  acc=63.6%
#   Epoch 46/200  |  Train  loss=1.1619  acc=58.2%  |  Val    loss=0.9939  acc=64.2%
#   Epoch 47/200  |  Train  loss=1.1589  acc=58.2%  |  Val    loss=0.9885  acc=64.3%
#   Epoch 48/200  |  Train  loss=1.1471  acc=58.6%  |  Val    loss=0.9911  acc=64.0%
#   Epoch 49/200  |  Train  loss=1.1420  acc=59.0%  |  Val    loss=0.9710  acc=64.6%
#   Epoch 196/200  |  Train  loss=0.7775  acc=72.6%  |  Val    loss=0.6514  acc=77.1%
#   Epoch 197/200  |  Train  loss=0.7780  acc=72.4%  |  Val    loss=0.6411  acc=77.5%
#   Epoch 198/200  |  Train  loss=0.7782  acc=72.5%  |  Val    loss=0.6464  acc=77.4%
#   Epoch 199/200  |  Train  loss=0.7736  acc=72.5%  |  Val    loss=0.6427  acc=77.4%
#   Epoch 200/200  |  Train  loss=0.7717  acc=72.7%  |  Val    loss=0.6516  acc=76.9%
#
#   ✓ Restored best checkpoint  (val acc = 77.45%)
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>batch_loss</td><td>█▇▆▃▃▄▃▂▂▃▃▄▄▂▃▂▂▃▃▃▂▂▃▃▂▂▂▃▂▁▂▂▁▂▂▂▂▂▁▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>train_accuracy</td><td>▁▁▂▃▄▄▄▅▅▅▅▅▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇██████████</td></tr><tr><td>train_loss</td><td>█▇▇▆▆▅▅▅▅▄▄▄▄▄▄▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▁▂▂▃▄▄▄▄▄▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇█████</td></tr><tr><td>val_loss</td><td>█▆▅▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>batch_loss</td><td>0.57593</td></tr><tr><td>best_val_accuracy</td><td>77.45</td></tr><tr><td>epoch</td><td>200</td></tr><tr><td>test_accuracy</td><td>77.09</td></tr><tr><td>test_loss</td><td>0.6524</td></tr><tr><td>train_accuracy</td><td>72.7325</td></tr><tr><td>train_loss</td><td>0.7717</td></tr><tr><td>val_accuracy</td><td>76.87</td></tr><tr><td>val_loss</td><td>0.65159</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Task01_CNN_SGD_LeakyReLU</strong> at: <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/6kknw33l' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/6kknw33l</a><br> View project at: <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code></code>
# ──────────────────────────────────────────────────────────────
#   ✓ Task01_CNN_SGD_LeakyReLU
#     Best Val Accuracy  : 77.45%
#     Final Test Accuracy: 77.09%
#     W&B dashboard      : https://wandb.ai
# ──────────────────────────────────────────────────────────────
#
# [Result] Experiment : Task01_CNN_SGD_LeakyReLU
# [Result] Best Validation Accuracy : 77.45%
# [Result] Optimiser: SGD | LR: 0.0001 | Activation: LeakyReLU

# %%
# 1.2  Adam + LeakyReLU — swap optimiser, keep everything else the same
from experiments.task01_cnn_adam_leakyrelu import main as run_adam_leakyrelu
run_adam_leakyrelu()
# Out:
# Device: cuda
# GPU   : NVIDIA GeForce RTX 2080 Ti
#
# Loading CIFAR-10 …
# /usr/local/lib/python3.11/dist-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# CIFAR-10 ready | train: 40,000 | val: 10,000 | test: 10,000 | image size: 32×32
#
# Building SimpleCNN (LeakyReLU) …
# Total parameters: 1,276,682
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/wandb/run-20260404_152754-fc8bsk93</code>
# Syncing run <strong><a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/fc8bsk93' target="_blank">Task01_CNN_Adam_LeakyReLU</a></strong> to <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0</a>
#  View run at <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/fc8bsk93' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/fc8bsk93</a>
# ══════════════════════════════════════════════════════════════
#   Experiment  : Task01_CNN_Adam_LeakyReLU
#   Device      : cuda  (NVIDIA GeForce RTX 2080 Ti)
#   Optimiser   : Adam  lr=0.0001
#   Epochs      : 200
#   Trainable   : 1,276,682 parameters
#   Split       : 70% train / 15% val / 15% test
#   W&B project : advanced-ai-lab-0  (view at https://wandb.ai)
# ══════════════════════════════════════════════════════════════
#   Epoch  1/200  |  Train  loss=1.7178  acc=36.5%  |  Val    loss=1.3590  acc=50.3%
#   Epoch  2/200  |  Train  loss=1.4226  acc=47.9%  |  Val    loss=1.2186  acc=55.6%
#   Epoch  3/200  |  Train  loss=1.3017  acc=52.9%  |  Val    loss=1.1161  acc=60.0%
#   Epoch  4/200  |  Train  loss=1.2172  acc=56.0%  |  Val    loss=1.0136  acc=64.1%
#   Epoch  5/200  |  Train  loss=1.1661  acc=57.9%  |  Val    loss=0.9552  acc=66.0%
#   Epoch  6/200  |  Train  loss=1.1128  acc=59.8%  |  Val    loss=0.9412  acc=66.5%
#   Epoch  7/200  |  Train  loss=1.0849  acc=60.7%  |  Val    loss=0.8934  acc=68.1%
#   Epoch  8/200  |  Train  loss=1.0413  acc=62.7%  |  Val    loss=0.8950  acc=68.0%
#   Epoch  9/200  |  Train  loss=1.0176  acc=63.5%  |  Val    loss=0.8482  acc=70.6%
#   Epoch 10/200  |  Train  loss=0.9860  acc=65.0%  |  Val    loss=0.8625  acc=68.8%
#   Epoch 11/200  |  Train  loss=0.9595  acc=65.7%  |  Val    loss=0.8030  acc=71.9%
#   Epoch 12/200  |  Train  loss=0.9471  acc=66.3%  |  Val    loss=0.7933  acc=71.8%
#   Epoch 13/200  |  Train  loss=0.9336  acc=66.6%  |  Val    loss=0.7714  acc=73.3%
#   Epoch 14/200  |  Train  loss=0.9096  acc=67.8%  |  Val    loss=0.7482  acc=74.0%
#   Epoch 15/200  |  Train  loss=0.8955  acc=67.9%  |  Val    loss=0.7335  acc=74.6%
#   Epoch 16/200  |  Train  loss=0.8810  acc=68.7%  |  Val    loss=0.7243  acc=75.0%
#   Epoch 191/200  |  Train  loss=0.3760  acc=86.6%  |  Val    loss=0.3959  acc=86.6%
#   Epoch 192/200  |  Train  loss=0.3710  acc=86.8%  |  Val    loss=0.3974  acc=86.6%
#   Epoch 193/200  |  Train  loss=0.3726  acc=86.8%  |  Val    loss=0.4000  acc=86.3%
#   Epoch 194/200  |  Train  loss=0.3725  acc=86.7%  |  Val    loss=0.4003  acc=86.4%
#   Epoch 195/200  |  Train  loss=0.3720  acc=86.6%  |  Val    loss=0.3967  acc=86.6%
#   Epoch 196/200  |  Train  loss=0.3734  acc=86.6%  |  Val    loss=0.3935  acc=86.8%
#   Epoch 197/200  |  Train  loss=0.3742  acc=86.8%  |  Val    loss=0.3951  acc=86.5%
#   Epoch 198/200  |  Train  loss=0.3699  acc=86.9%  |  Val    loss=0.3904  acc=86.7%
#   Epoch 199/200  |  Train  loss=0.3660  acc=87.0%  |  Val    loss=0.3937  acc=86.5%
#   Epoch 200/200  |  Train  loss=0.3701  acc=86.8%  |  Val    loss=0.3927  acc=86.6%
#
#   ✓ Restored best checkpoint  (val acc = 86.78%)
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>batch_loss</td><td>▆█▆▄▅▅▅▅▅▄▃▄▃▂▃▃▂▃▃▂▃▄▃▃▃▃▂▃▂▂▂▁▁▃▁▃▂▂▂▂</td></tr><tr><td>epoch</td><td>▁▁▁▁▁▂▂▂▂▂▃▃▃▄▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇█████</td></tr><tr><td>train_accuracy</td><td>▁▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇███████████████████</td></tr><tr><td>train_loss</td><td>█▆▅▄▄▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇████████████</td></tr><tr><td>val_loss</td><td>█▅▅▅▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>batch_loss</td><td>0.28464</td></tr><tr><td>best_val_accuracy</td><td>86.78</td></tr><tr><td>epoch</td><td>200</td></tr><tr><td>test_accuracy</td><td>85.59</td></tr><tr><td>test_loss</td><td>0.42176</td></tr><tr><td>train_accuracy</td><td>86.825</td></tr><tr><td>train_loss</td><td>0.37009</td></tr><tr><td>val_accuracy</td><td>86.56</td></tr><tr><td>val_loss</td><td>0.39274</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Task01_CNN_Adam_LeakyReLU</strong> at: <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/fc8bsk93' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/fc8bsk93</a><br> View project at: <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code></code>
# ──────────────────────────────────────────────────────────────
#   ✓ Task01_CNN_Adam_LeakyReLU
#     Best Val Accuracy  : 86.78%
#     Final Test Accuracy: 85.59%
#     W&B dashboard      : https://wandb.ai
# ──────────────────────────────────────────────────────────────
#
# [Result] Experiment : Task01_CNN_Adam_LeakyReLU
# [Result] Best Test Accuracy : 86.78%
# [Result] Optimiser: Adam | LR: 0.0001 | Activation: LeakyReLU

# %%
# 1.3  Adam + Tanh — swap activation function (this is the required separate file)
from experiments.task01_cnn_adam_tanh import main as run_adam_tanh
run_adam_tanh()
# Out:
# Device: cuda
# GPU   : NVIDIA GeForce RTX 2080 Ti
#
# Loading CIFAR-10 …
# /usr/local/lib/python3.11/dist-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# CIFAR-10 ready | train: 40,000 | val: 10,000 | test: 10,000 | image size: 32×32
#
# Building SimpleCNN (Tanh) …
# Total parameters: 1,276,682
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/wandb/run-20260404_160133-bw2wpjdt</code>
# Syncing run <strong><a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/bw2wpjdt' target="_blank">Task01_CNN_Adam_Tanh</a></strong> to <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0</a>
#  View run at <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/bw2wpjdt' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/bw2wpjdt</a>
# ══════════════════════════════════════════════════════════════
#   Experiment  : Task01_CNN_Adam_Tanh
#   Device      : cuda  (NVIDIA GeForce RTX 2080 Ti)
#   Optimiser   : Adam  lr=0.0001
#   Epochs      : 200
#   Trainable   : 1,276,682 parameters
#   Split       : 70% train / 15% val / 15% test
#   W&B project : advanced-ai-lab-0  (view at https://wandb.ai)
# ══════════════════════════════════════════════════════════════
#   Epoch  1/200  |  Train  loss=1.6831  acc=38.7%  |  Val    loss=1.3670  acc=51.0%
#   Epoch  2/200  |  Train  loss=1.4468  acc=47.5%  |  Val    loss=1.2448  acc=55.1%
#   Epoch  3/200  |  Train  loss=1.3541  acc=51.3%  |  Val    loss=1.1951  acc=56.8%
#   Epoch  4/200  |  Train  loss=1.2988  acc=53.4%  |  Val    loss=1.1061  acc=60.2%
#   Epoch  5/200  |  Train  loss=1.2430  acc=55.4%  |  Val    loss=1.0898  acc=61.2%
#   Epoch  6/200  |  Train  loss=1.2023  acc=56.8%  |  Val    loss=1.0358  acc=62.7%
#   Epoch  7/200  |  Train  loss=1.1695  acc=58.1%  |  Val    loss=1.0253  acc=63.6%
#   Epoch  8/200  |  Train  loss=1.1413  acc=59.4%  |  Val    loss=0.9664  acc=65.3%
#   Epoch  9/200  |  Train  loss=1.1134  acc=60.2%  |  Val    loss=0.9358  acc=66.7%
#   Epoch 10/200  |  Train  loss=1.0898  acc=61.1%  |  Val    loss=0.9226  acc=67.0%
#   Epoch 11/200  |  Train  loss=1.0645  acc=62.0%  |  Val    loss=0.9181  acc=67.2%
#   Epoch 12/200  |  Train  loss=1.0514  acc=62.4%  |  Val    loss=0.8924  acc=68.5%
Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code></code>
# ──────────────────────────────────────────────────────────────
#   ✓ Task01_CNN_Adam_Tanh
#     Best Val Accuracy  : 83.23%
#     Final Test Accuracy: 81.76%
#     W&B dashboard      : https://wandb.ai
# ──────────────────────────────────────────────────────────────
#
# [Result] Experiment : Task01_CNN_Adam_Tanh
# [Result] Best Test Accuracy : 83.23%
# [Result] Optimiser: Adam | LR: 0.0001 | Activation: Tanh

# %% [markdown]
# ---
# ## Section 2 — Task 0.2.1: AlexNet Transfer Learning on CIFAR-10
#
# AlexNet was pretrained on **ImageNet** (1,000 classes, 224×224 images).
# We adapt it for **CIFAR-10** (10 classes) two different ways:
#
# - **Fine-tuning** — all layers are updated → higher accuracy, more compute
# - **Feature extraction** — backbone is frozen, only the final layer trains → faster, slightly lower accuracy
#
# In both cases the original last layer `Linear(4096 → 1000)` is replaced with `Linear(4096 → 10)`.

# %%
# 2.1  AlexNet — Full Fine-Tuning (all layers updated)
from experiments.task02_alexnet_finetune import main as run_alexnet_finetune
run_alexnet_finetune()
# Out:
# Device: cuda
# GPU   : NVIDIA GeForce RTX 2080 Ti
#
# Loading CIFAR-10 (upscaled to 224×224 for AlexNet) …
# /usr/local/lib/python3.11/dist-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# CIFAR-10 ready | train: 40,000 | val: 10,000 | test: 10,000 | image size: 224×224
#
# Building AlexNet (pretrained=True, all layers trainable) …
# AlexNet (Fine-Tuning):
#   Total parameters     : 57,044,810
#   Trainable parameters : 57,044,810
#   Frozen parameters    : 0
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/wandb/run-20260404_163536-ik6o8g9u</code>
# Syncing run <strong><a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/ik6o8g9u' target="_blank">Task02_AlexNet_FineTuning</a></strong> to <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0</a>
#  View run at <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/ik6o8g9u' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/ik6o8g9u</a>
# ══════════════════════════════════════════════════════════════
#   Experiment  : Task02_AlexNet_FineTuning
#   Device      : cuda  (NVIDIA GeForce RTX 2080 Ti)
#   Optimiser   : Adam  lr=0.0001
#   Epochs      : 50
#   Trainable   : 57,044,810 parameters
#   Split       : 70% train / 15% val / 15% test
#   W&B project : advanced-ai-lab-0  (view at https://wandb.ai)
# ══════════════════════════════════════════════════════════════
#   Epoch  1/50  |  Train  loss=0.6141  acc=78.8%  |  Val    loss=0.4405  acc=84.6%
#   Epoch  2/50  |  Train  loss=0.4045  acc=86.0%  |  Val    loss=0.3540  acc=87.6%
#   Epoch  3/50  |  Train  loss=0.3284  acc=88.7%  |  Val    loss=0.2991  acc=89.4%
#   Epoch  4/50  |  Train  loss=0.2817  acc=90.2%  |  Val    loss=0.3233  acc=89.2%
#   Epoch 34/50  |  Train  loss=0.0604  acc=98.0%  |  Val    loss=0.3541  acc=90.8%
#   Epoch 35/50  |  Train  loss=0.0677  acc=97.8%  |  Val    loss=0.3437  acc=91.1%
#   Epoch 36/50  |  Train  loss=0.0646  acc=97.8%  |  Val    loss=0.3561  acc=91.0%
#   Epoch 37/50  |  Train  loss=0.0685  acc=97.8%  |  Val    loss=0.3758  acc=90.8%
#   Epoch 38/50  |  Train  loss=0.0636  acc=97.9%  |  Val    loss=0.4208  acc=90.3%
#   Epoch 39/50  |  Train  loss=0.0630  acc=97.9%  |  Val    loss=0.3335  acc=91.7%
#   Epoch 40/50  |  Train  loss=0.0591  acc=98.1%  |  Val    loss=0.3700  acc=90.8%
#   Epoch 41/50  |  Train  loss=0.0640  acc=98.0%  |  Val    loss=0.3250  acc=92.0%
#   Epoch 42/50  |  Train  loss=0.0649  acc=97.9%  |  Val    loss=0.3760  acc=90.5%
#   Epoch 43/50  |  Train  loss=0.0629  acc=98.0%  |  Val    loss=0.3797  acc=91.0%
#   Epoch 44/50  |  Train  loss=0.0607  acc=98.1%  |  Val    loss=0.3345  acc=91.2%
#   Epoch 45/50  |  Train  loss=0.0612  acc=98.0%  |  Val    loss=0.3487  acc=91.2%
#   Epoch 46/50  |  Train  loss=0.0588  acc=98.1%  |  Val    loss=0.3704  acc=91.0%
#   Epoch 47/50  |  Train  loss=0.0600  acc=98.1%  |  Val    loss=0.3637  acc=91.3%
#   Epoch 48/50  |  Train  loss=0.0605  acc=98.0%  |  Val    loss=0.3823  acc=89.8%
#   Epoch 49/50  |  Train  loss=0.0598  acc=98.1%  |  Val    loss=0.3499  acc=90.9%
#   Epoch 50/50  |  Train  loss=0.0570  acc=98.2%  |  Val    loss=0.3595  acc=91.4%
#
#   ✓ Restored best checkpoint  (val acc = 91.95%)
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>batch_loss</td><td>▇▄▅▄▇█▅▂▄▁▁▃▃▅▂▁▁▁▂▂▂▁▁▁▂▂▂▃▁▅▄▂▁▂▁▁▂▂▁▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_accuracy</td><td>▁▄▅▅▆▆▆▇▇▇▇▇▇▇▇█████████████████████████</td></tr><tr><td>train_loss</td><td>█▅▄▄▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▆▅▆▆▆▆▇▆▆▆▇▆█▆▇▇▇▇▇▇▇▇█▇▇▇▇▇▇█▇█▇▇▇▇▇▆▇</td></tr><tr><td>val_loss</td><td>█▄▁▂▁▁▁▂▂▁▂▂▂▂▁▅▅▂▂▃▂▂▂▃▂▂▄▃▄▅▃▅▂▅▅▃▅▄▅▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>batch_loss</td><td>0.00644</td></tr><tr><td>best_val_accuracy</td><td>91.95</td></tr><tr><td>epoch</td><td>50</td></tr><tr><td>test_accuracy</td><td>91.09</td></tr><tr><td>test_loss</td><td>0.37293</td></tr><tr><td>train_accuracy</td><td>98.22</td></tr><tr><td>train_loss</td><td>0.05697</td></tr><tr><td>val_accuracy</td><td>91.38</td></tr><tr><td>val_loss</td><td>0.35951</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Task02_AlexNet_FineTuning</strong> at: <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/ik6o8g9u' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/ik6o8g9u</a><br> View project at: <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code></code>
# ──────────────────────────────────────────────────────────────
#   ✓ Task02_AlexNet_FineTuning
#     Best Val Accuracy  : 91.95%
#     Final Test Accuracy: 91.09%
#     W&B dashboard      : https://wandb.ai
# ──────────────────────────────────────────────────────────────
#
# [Result] Experiment : Task02_AlexNet_FineTuning
# [Result] Best Test Accuracy : 91.95%
# [Result] Mode: Fine-Tuning (all layers updated)

# %%
# 2.2  AlexNet — Feature Extraction (backbone frozen, only FC head trains)
from experiments.task02_alexnet_feature_extraction import main as run_alexnet_features
run_alexnet_features()
# Out:
# Device: cuda
# GPU   : NVIDIA GeForce RTX 2080 Ti
#
# Loading CIFAR-10 (upscaled to 224×224 for AlexNet) …
# /usr/local/lib/python3.11/dist-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# CIFAR-10 ready | train: 40,000 | val: 10,000 | test: 10,000 | image size: 224×224
#
# Building AlexNet (backbone frozen, only FC head trains) …
# AlexNet (Feature Extraction):
#   Total parameters     : 57,044,810
#   Trainable parameters : 40,970
#   Frozen parameters    : 57,003,840
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/wandb/run-20260404_172353-5zy6y6w8</code>
# Syncing run <strong><a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/5zy6y6w8' target="_blank">Task02_AlexNet_FeatureExtraction</a></strong> to <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0</a>
#  View run at <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/5zy6y6w8' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/5zy6y6w8</a>
# ══════════════════════════════════════════════════════════════
#   Experiment  : Task02_AlexNet_FeatureExtraction
#   Device      : cuda  (NVIDIA GeForce RTX 2080 Ti)
#   Optimiser   : Adam  lr=0.001
#   Epochs      : 50
#   Trainable   : 40,970 parameters
#   Split       : 70% train / 15% val / 15% test
#   W&B project : advanced-ai-lab-0  (view at https://wandb.ai)
# ══════════════════════════════════════════════════════════════
#   Epoch  1/50  |  Train  loss=0.8366  acc=71.2%  |  Val    loss=0.6032  acc=79.2%
#   Epoch  2/50  |  Train  loss=0.7569  acc=74.1%  |  Val    loss=0.5778  acc=80.0%
#   Epoch  3/50  |  Train  loss=0.7504  acc=75.0%  |  Val    loss=0.5963  acc=80.0%
td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Task02_AlexNet_FeatureExtraction</strong> at: <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/5zy6y6w8' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/5zy6y6w8</a><br> View project at: <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code></code>
# ──────────────────────────────────────────────────────────────
#   ✓ Task02_AlexNet_FeatureExtraction
#     Best Val Accuracy  : 81.69%
#     Final Test Accuracy: 81.00%
#     W&B dashboard      : https://wandb.ai
# ──────────────────────────────────────────────────────────────
#
# [Result] Experiment : Task02_AlexNet_FeatureExtraction
# [Result] Best Test Accuracy : 81.69%
# [Result] Mode: Feature Extraction (backbone frozen)
#
# Why is feature extraction usually lower than fine-tuning?
#   AlexNet's backbone learned ImageNet patterns (1000 classes, high-res).
#   CIFAR-10 images are only 32×32 with 10 classes — a different distribution.
#   Because we cannot adjust the backbone, some feature mismatch remains.
#   Fine-tuning resolves this by updating every layer on CIFAR-10 data.

# %% [markdown]
# ---
# ## Section 3 — Task 0.2.2: Transfer Learning from MNIST → SVHN
#
# The cell below runs two stages automatically:
#
# **Stage 1** — Train a CNN from scratch on MNIST (clean handwritten digits, 28×28 grayscale).  Save the weights.
# **Stage 2** — Load those weights. Freeze the feature extractor. Fine-tune only the classifier on SVHN (real street-sign digits).
#
# SVHN images are converted to grayscale and resized to 28×28 so the **exact same architecture** works on both datasets.
#
# > **Grade-5 larger dataset**: set `"use_extra_data": True` in `config.py → SVHN_TRANSFER_CONFIG`
# > to also download the SVHN *extra* split (~531 K images, ~1 GB).

# %%
# 3.1  Stage 1: Train on MNIST  →  Stage 2: Transfer to SVHN
from experiments.task02_mnist_to_svhn import main as run_mnist_to_svhn
run_mnist_to_svhn()
# Out:
# Device: cuda
# GPU   : NVIDIA GeForce RTX 2080 Ti
#
# ══════════════════════════════════════════════════════════════
#   STAGE 1 — Train CNN on MNIST
# ══════════════════════════════════════════════════════════════
# MNIST ready | train: 48,000 | val: 12,000 | test: 10,000 | image size: 28×28 | channels: 1 (grayscale)
# MnistCNN parameters: 1,630,282
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/wandb/run-20260404_180930-lmolskqt</code>
# Syncing run <strong><a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/lmolskqt' target="_blank">Task02_MNIST_Training</a></strong> to <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0</a>
#  View run at <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/lmolskqt' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/lmolskqt</a>
# ══════════════════════════════════════════════════════════════
#   Experiment  : Task02_MNIST_Training
#   Device      : cuda  (NVIDIA GeForce RTX 2080 Ti)
#   Optimiser   : Adam  lr=0.001
#   Epochs      : 100
#   Trainable   : 1,630,282 parameters
#   Split       : 70% train / 15% val / 15% test
#   W&B project : advanced-ai-lab-0  (view at https://wandb.ai)
# ══════════════════════════════════════════════════════════════
#   Epoch  1/100  |  Train  loss=0.1851  acc=94.1%  |  Val    loss=0.0609  acc=98.1%
#   Epoch  2/100  |  Train  loss=0.0822  acc=97.4%  |  Val    loss=0.0437  acc=98.6%
#   Epoch  3/100  |  Train  loss=0.0627  acc=98.0%  |  Val    loss=0.0441  acc=98.8%
#   Epoch  4/100  |  Train  loss=0.0563  acc=98.2%  |  Val    loss=0.0365  acc=99.0%
#   Epoch  5/100  |  Train  loss=0.0462  acc=98.5%  |  Val    loss=0.0330  acc=99.0%
#   Epoch  6/100  |  Train  loss=0.0425  acc=98.6%  |  Val    loss=0.0352  acc=98.9%
#   Epoch  7/100  |  Train  loss=0.0380  acc=98.7%  |  Val    loss=0.0288  acc=99.2%
#   Epoch  8/100  |  Train  loss=0.0344  acc=98.9%  |  Val    loss=0.0312  acc=99.1%
#   Epoch  9/100  |  Train  loss=0.0315  acc=99.0%  |  Val    loss=0.0396  acc=98.9%
#   Epoch 10/100  |  Train  loss=0.0304  acc=99.0%  |  Val    loss=0.0302  acc=99.1%
#   Epoch 11/100  |  Train  loss=0.0271  acc=99.2%  |  Val    loss=0.0259  acc=99.3%
#   Epoch 12/100  |  Train  loss=0.0249  acc=99.2%  |  Val    loss=0.0262  acc=99.3%
#   Epoch 13/100  |  Train  loss=0.0256  acc=99.2%  |  Val    loss=0.0244  acc=99.3%
#   Epoch 14/100  |  Train  loss=0.0234  acc=99.2%  |  Val    loss=0.0270  acc=99.3%
#   Epoch 15/100  |  Train  loss=0.0193  acc=99.4%  |  Val    loss=0.0252  acc=99.4%
#   Epoch 16/100  |  Train  loss=0.0213  acc=99.3%  |  Val    loss=0.0275  acc=99.3%
#   Epoch 17/100  |  Train  loss=0.0191  acc=99.4%  |  Val    loss=0.0240  acc=99.3%
#   Epoch 18/100  |  Train  loss=0.0161  acc=99.4%  |  Val    loss=0.0313  acc=99.2%
#   Epoch 19/100  |  Train  loss=0.0181  acc=99.4%  |  Val    loss=0.0239  acc=99.3%
#   Epoch 20/100  |  Train  loss=0.0166  acc=99.4%  |  Val    loss=0.0299  acc=99.2%
#   Epoch 21/100  |  Train  loss=0.0157  acc=99.5%  |  Val    loss=0.0290  acc=99.2%
#   Epoch 22/100  |  Train  loss=0.0152  acc=99.5%  |  Val    loss=0.0260  acc=99.3%
#   Epoch 23/100  |  Train  loss=0.0158  acc=99.5%  |  Val    loss=0.0279  acc=99.3%
#   Epoch 24/100  |  Train  loss=0.0150  acc=99.5%  |  Val    loss=0.0250  acc=99.3%
#   Epoch 84/100  |  Train  loss=0.0068  acc=99.8%  |  Val    loss=0.0339  acc=99.4%
#   Epoch 85/100  |  Train  loss=0.0045  acc=99.8%  |  Val    loss=0.0379  acc=99.4%
#   Epoch 86/100  |  Train  loss=0.0045  acc=99.9%  |  Val    loss=0.0434  acc=99.4%
#   Epoch 87/100  |  Train  loss=0.0059  acc=99.8%  |  Val    loss=0.0422  acc=99.3%
#   Epoch 88/100  |  Train  loss=0.0062  acc=99.8%  |  Val    loss=0.0408  acc=99.4%
#   Epoch 89/100  |  Train  loss=0.0081  acc=99.8%  |  Val    loss=0.0399  acc=99.4%
#   Epoch 90/100  |  Train  loss=0.0064  acc=99.8%  |  Val    loss=0.0319  acc=99.5%
#   Epoch 91/100  |  Train  loss=0.0066  acc=99.8%  |  Val    loss=0.0368  acc=99.4%
#   Epoch 92/100  |  Train  loss=0.0038  acc=99.9%  |  Val    loss=0.0377  acc=99.3%
#   Epoch 93/100  |  Train  loss=0.0064  acc=99.8%  |  Val    loss=0.0371  acc=99.4%
#   Epoch 94/100  |  Train  loss=0.0070  acc=99.8%  |  Val    loss=0.0441  acc=99.4%
#   Epoch 95/100  |  Train  loss=0.0056  acc=99.8%  |  Val    loss=0.0407  acc=99.4%
#   Epoch 96/100  |  Train  loss=0.0054  acc=99.8%  |  Val    loss=0.0455  acc=99.4%
#   Epoch 97/100  |  Train  loss=0.0063  acc=99.8%  |  Val    loss=0.0405  acc=99.3%
#   Epoch 98/100  |  Train  loss=0.0065  acc=99.8%  |  Val    loss=0.0438  acc=99.4%
#   Epoch 99/100  |  Train  loss=0.0053  acc=99.8%  |  Val    loss=0.0433  acc=99.5%
#   Epoch 100/100  |  Train  loss=0.0043  acc=99.9%  |  Val    loss=0.0447  acc=99.4%
#
#   ✓ Restored best checkpoint  (val acc = 99.48%)
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>batch_loss</td><td>█▄▃▁▁▇▄▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▆█▁▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▅▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇█████</td></tr><tr><td>train_accuracy</td><td>▁▆▇▇▇███████████████████████████████████</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▆▅▅▆▇▇▇▇▇▇▇█▇▇▇███▇█████████▇█████████</td></tr><tr><td>val_loss</td><td>█▅▃▂▁▁▂▁▂▁▁▂▂▂▂▃▂▃▃▃▃▃▃▃▃▃▃▃▂▂▄▃▃▄▃▄▄▄▄▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>batch_loss</td><td>3e-05</td></tr><tr><td>best_val_accuracy</td><td>99.48333</td></tr><tr><td>epoch</td><td>100</td></tr><tr><td>test_accuracy</td><td>99.42</td></tr><tr><td>test_loss</td><td>0.03123</td></tr><tr><td>train_accuracy</td><td>99.87292</td></tr><tr><td>train_loss</td><td>0.0043</td></tr><tr><td>val_accuracy</td><td>99.41667</td></tr><tr><td>val_loss</td><td>0.04473</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Task02_MNIST_Training</strong> at: <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/lmolskqt' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/lmolskqt</a><br> View project at: <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code></code>
# ──────────────────────────────────────────────────────────────
#   ✓ Task02_MNIST_Training
#     Best Val Accuracy  : 99.48%
#     Final Test Accuracy: 99.42%
#     W&B dashboard      : https://wandb.ai
# ──────────────────────────────────────────────────────────────
#
# Checkpoint saved → /Labs/Lab0/checkpoints/mnist_cnn.pth
# [Stage 1 Result] MNIST Test Accuracy : 99.48%
#
#
# ══════════════════════════════════════════════════════════════
#   STAGE 2 — Transfer CNN from MNIST to SVHN
# ══════════════════════════════════════════════════════════════
# Downloading SVHN 'extra' split (~1 GB) for Grade-5 larger-dataset requirement …
# Combined train set size: 604,388 images
# SVHN (grayscale) ready | train: 483,511 | val: 120,877 | test: 26,032 | image size: 28×28 | channels: 1 | extra split: True
# Checkpoint loaded ← /Labs/Lab0/checkpoints/mnist_cnn.pth
# Feature extractor FROZEN — only the classifier will be updated.
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/wandb/run-20260404_182535-6u2u05p9</code>
# Syncing run <strong><a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/6u2u05p9' target="_blank">Task02_SVHN_Transfer</a></strong> to <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0</a>
#  View run at <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/6u2u05p9' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/6u2u05p9</a>
# ══════════════════════════════════════════════════════════════
#   Experiment  : Task02_SVHN_Transfer
#   Device      : cuda  (NVIDIA GeForce RTX 2080 Ti)
#   Optimiser   : Adam  lr=0.0001
#   Epochs      : 100
#   Trainable   : 1,611,274 parameters
#   Split       : 70% train / 15% val / 15% test
#   W&B project : advanced-ai-lab-0  (view at https://wandb.ai)
# ══════════════════════════════════════════════════════════════
#   Epoch  1/100  |  Train  loss=2.4006  acc=43.6%  |  Val    loss=1.0296  acc=73.1%
#   Epoch  2/100  |  Train  loss=1.0833  acc=65.3%  |  Val    loss=0.7296  acc=81.7%
#   Epoch  3/100  |  Train  loss=0.8898  acc=71.8%  |  Val    loss=0.6228  acc=84.6%
#   Epoch  4/100  |  Train  loss=0.7953  acc=74.9%  |  Val    loss=0.5433  acc=85.9%
#   Epoch  5/100  |  Train  loss=0.7370  acc=76.8%  |  Val    loss=0.5087  acc=86.9%
#   Epoch  6/100  |  Train  loss=0.6931  acc=78.1%  |  Val    loss=0.4820  acc=87.6%
#   Epoch  7/100  |  Train  loss=0.6624  acc=79.1%  |  Val    loss=0.4593  acc=87.9%
#   Epoch  8/100  |  Train  loss=0.6362  acc=79.9%  |  Val    loss=0.4443  acc=88.3%
#   Epoch 96/100  |  Train  loss=0.3375  acc=89.3%  |  Val    loss=0.2481  acc=93.4%
#   Epoch 97/100  |  Train  loss=0.3376  acc=89.4%  |  Val    loss=0.2477  acc=93.3%
#   Epoch 98/100  |  Train  loss=0.3373  acc=89.3%  |  Val    loss=0.2458  acc=93.4%
#   Epoch 99/100  |  Train  loss=0.3359  acc=89.4%  |  Val    loss=0.2459  acc=93.4%
#   Epoch 100/100  |  Train  loss=0.3348  acc=89.4%  |  Val    loss=0.2443  acc=93.4%
#
#   ✓ Restored best checkpoint  (val acc = 93.44%)
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>batch_loss</td><td>█▄▂▂▂▂▂▂▂▂▂▂▁▂▂▂▁▂▂▁▂▁▂▁▁▂▁▂▂▂▁▁▂▂▁▁▁▂▁▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>train_accuracy</td><td>▁▇▇▇▇▇▇▇▇▇▇▇▇▇██████████████████████████</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▂▄▄▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇███████████████████</td></tr><tr><td>val_loss</td><td>█▅▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>batch_loss</td><td>0.53045</td></tr><tr><td>best_val_accuracy</td><td>93.44375</td></tr><tr><td>epoch</td><td>100</td></tr><tr><td>test_accuracy</td><td>87.815</td></tr><tr><td>test_loss</td><td>0.4509</td></tr><tr><td>train_accuracy</td><td>89.44905</td></tr><tr><td>train_loss</td><td>0.33485</td></tr><tr><td>val_accuracy</td><td>93.4272</td></tr><tr><td>val_loss</td><td>0.24434</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Task02_SVHN_Transfer</strong> at: <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/6u2u05p9' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/6u2u05p9</a><br> View project at: <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code></code>
# ──────────────────────────────────────────────────────────────
#   ✓ Task02_SVHN_Transfer
#     Best Val Accuracy  : 93.44%
#     Final Test Accuracy: 87.81%
#     W&B dashboard      : https://wandb.ai
# ──────────────────────────────────────────────────────────────
#
# [Stage 2 Result] SVHN Test Accuracy (after transfer) : 93.44%
#
# ══════════════════════════════════════════════════════════════
#   Task 0.2.2 Summary
# ──────────────────────────────────────────────────────────────
#   MNIST accuracy (source task)           : 99.48%
#   SVHN accuracy  (after transfer learning): 93.44%
# ══════════════════════════════════════════════════════════════
#
# Expected behaviour:
#   MNIST accuracy is typically 99%+.
#   SVHN accuracy after transfer is lower (often 60–80%) because
#   SVHN images are noisier and harder than MNIST.
#   To improve SVHN accuracy, try un-freezing all layers (full fine-tuning).

# %% [markdown]
# ---
# ## Section 4 — Grade 5: Two Transformer Models on CIFAR-10
#
# Runs **ViT-B/16** and **Swin-T** back-to-back, both pretrained on ImageNet and fine-tuned for CIFAR-10.
#
# - **ViT-B/16** — splits image into 16×16 patches, applies global self-attention across all patches
# - **Swin-T** — uses local shifted-window attention in a hierarchical layout, more memory-efficient
#
# > ⚠ GPU strongly recommended. On CPU, reduce `"epochs"` in `config.py` (e.g. to `1`) to save time.

# %%
# 4.1  ViT-B/16 + Swin-T on CIFAR-10
from experiments.grade5_transformers_cifar10 import main as run_transformers
run_transformers()
# Out:
# Device: cuda
# GPU   : NVIDIA GeForce RTX 2080 Ti
#
# Loading CIFAR-10 (224×224, batch=16) …
# /usr/local/lib/python3.11/dist-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# CIFAR-10 ready | train: 40,000 | val: 10,000 | test: 10,000 | image size: 224×224
#
# Building ViT-B/16 (pretrained on ImageNet) …
# ViT-B/16:
#   Total parameters     : 85,806,346
#   Trainable parameters : 85,806,346
#
# ▶▶▶  Starting transformer experiment: Grade5_ViT_B16_CIFAR10
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/wandb/run-20260404_210131-1wn60trl</code>
# Syncing run <strong><a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/1wn60trl' target="_blank">Grade5_ViT_B16_CIFAR10</a></strong> to <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0</a>
#  View run at <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/1wn60trl' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/1wn60trl</a>
# ══════════════════════════════════════════════════════════════
#   Experiment  : Grade5_ViT_B16_CIFAR10
#   Device      : cuda  (NVIDIA GeForce RTX 2080 Ti)
#   Optimiser   : Adam  lr=0.0001
#   Epochs      : 5
#   Trainable   : 85,806,346 parameters
#   Split       : 70% train / 15% val / 15% test
#   W&B project : advanced-ai-lab-0  (view at https://wandb.ai)
# ══════════════════════════════════════════════════════════════
#   Epoch  1/5  |  Train  loss=0.3402  acc=88.8%  |  Val    loss=0.2080  acc=92.9%
#   Epoch  2/5  |  Train  loss=0.2188  acc=92.6%  |  Val    loss=0.1965  acc=93.4%
#   Epoch  3/5  |  Train  loss=0.1774  acc=94.0%  |  Val    loss=0.1932  acc=93.3%
#   Epoch  4/5  |  Train  loss=0.1531  acc=94.7%  |  Val    loss=0.1831  acc=93.9%
#   Epoch  5/5  |  Train  loss=0.1278  acc=95.6%  |  Val    loss=0.2211  acc=92.5%
#
#   ✓ Restored best checkpoint  (val acc = 93.93%)
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>batch_loss</td><td>▅▆▆▃▂▃▄▆▃▅▅▁▃▆▅▂▂▁▅▂▆▂▂▃▂▇▁▅▃▅▁▁▄▂▃▁▄▃▃█</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>train_accuracy</td><td>▁▅▆▇█</td></tr><tr><td>train_loss</td><td>█▄▃▂▁</td></tr><tr><td>val_accuracy</td><td>▃▅▅█▁</td></tr><tr><td>val_loss</td><td>▆▃▃▁█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>batch_loss</td><td>0.05107</td></tr><tr><td>best_val_accuracy</td><td>93.93</td></tr><tr><td>epoch</td><td>5</td></tr><tr><td>test_accuracy</td><td>93.57</td></tr><tr><td>test_loss</td><td>0.19587</td></tr><tr><td>train_accuracy</td><td>95.5875</td></tr><tr><td>train_loss</td><td>0.12775</td></tr><tr><td>val_accuracy</td><td>92.54</td></tr><tr><td>val_loss</td><td>0.22108</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Grade5_ViT_B16_CIFAR10</strong> at: <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/1wn60trl' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0/runs/1wn60trl</a><br> View project at: <a href='https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0' target="_blank">https://wandb.ai/deeplab15group-lule-university-of-technology/advanced-ai-lab-0</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code></code>
# ──────────────────────────────────────────────────────────────
#   ✓ Grade5_ViT_B16_CIFAR10
#     Best Val Accuracy  : 93.93%
#     Final Test Accuracy: 93.57%
#     W&B dashboard      : https://wandb.ai
# ──────────────────────────────────────────────────────────────
#
# [Result] Grade5_ViT_B16_CIFAR10 — Best Val Accuracy: 93.93%
#
# Building Swin-T (pretrained on ImageNet) …
# Swin-T:
#   Total parameters     : 27,527,044
#   Trainable parameters : 27,527,044
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 # 4.1  ViT-B/16 + Swin-T on CIFAR-10
#       2 from experiments.grade5_transformers_cifar10 import main as run_transformers
# ----> 3 run_transformers()
#
# File /Labs/Lab0/experiments/grade5_transformers_cifar10.py:138, in main()
#     130 swin_config = {**config.SWIN_CONFIG, "device": config.DEVICE}
#     131 swin_config.pop("image_size", None)
#     133 results["Swin-T"] = run_transformer_experiment(
#     134     model_name   = "Grade5_SwinT_CIFAR10",
#     135     model        = swin_model,
#     136     exp_config   = swin_config,
#     137     train_loader = swin_train,
# --> 138     val_loader   = swin_val,
#     139     test_loader  = swin_test,
#     140 )
#     142 # ── Summary ──────────────────────────────────────────────────────────── #
#     143 print("\n" + "═" * 62)
#
# UnboundLocalError: cannot access local variable 'swin_val' where it is not associated with a value

# %% [markdown]
# ---
# ## Section 5 — Weights & Biases: View All Results
#
# All experiments automatically log to **https://wandb.ai** — no local server needed, no port forwarding required.
#
# ### First-time setup (run once)
# Run cell 17 below — it installs wandb (if missing) and logs you in with your API key.
# Get your key at: **https://wandb.ai/authorize**
#
# ### Viewing results
# Open **https://wandb.ai** in any browser — all runs are grouped under project **`advanced-ai-lab`**.
# Use the **Charts** panel to compare training curves from all experiments side-by-side.
#
# > To rename the project, change `WANDB_PROJECT` in `config.py`.

# %%
# 5.1  Log in to Weights & Biases (run once)
# This installs wandb if needed, then opens a login prompt.
# Paste your API key from https://wandb.ai/authorize when prompted.

import subprocess, sys

# Install wandb if not already present
subprocess.run([sys.executable, "-m", "pip", "install", "-q", "wandb"], check=True)

# %% [markdown]
# # Advanced AI Lab — Main Notebook
#
# This is the **single entry point** for all lab experiments.
# Run the cells top-to-bottom in each section you need.
# All heavy logic lives in the project files — this notebook just calls them.
#
# | Section | Task |
# |---|---|
# | 0 — Setup | Check GPU, verify imports |
# | 1 — Task 0.1 | Simple CNN: SGD vs Adam vs Tanh |
# | 2 — Task 0.2.1 | AlexNet transfer learning on CIFAR-10 |
# | 3 — Task 0.2.2 | MNIST → SVHN transfer learning |
# | 4 — Grade 5 | ViT-B/16 + Swin Transformer on CIFAR-10 |
# | 5 — TensorBoard | Visualise all experiment results |

# %% [markdown]
# ---
# ## Section 0 — Setup
#
# Run this cell once before anything else.
# It checks that PyTorch is installed and shows whether a GPU is available.

# %%
import sys
import os

# Make sure the project root is on the Python path so all imports work
project_root = "/Labs/Lab0"
sys.path.insert(0, project_root)

import torch
import config

import wandb


print("=" * 50)
print(f"PyTorch version : {torch.__version__}")
print(f"CUDA available  : {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU name        : {torch.cuda.get_device_name(0)}")
print(f"Device in use   : {config.DEVICE}")
print("=" * 50)
print("\nAll project modules are ready.")
print("Run any section below to start an experiment.")
# Out:
# ==================================================
# PyTorch version : 2.11.0+cu130
# CUDA available  : True
# GPU name        : NVIDIA GeForce RTX 2080 Ti
# Device in use   : cuda
# ==================================================
#
# All project modules are ready.
# Run any section below to start an experiment.

# %% [markdown]
# ---
# ## Section 1 — Task 0.1: Simple CNN on CIFAR-10
#
# Three experiments with the **same CNN architecture**, changing only one thing at a time:
#
# | Cell | Optimiser | Activation | What we learn |
# |---|---|---|---|
# | 1.1 | SGD | LeakyReLU | Baseline |
# | 1.2 | **Adam** | LeakyReLU | Effect of a better optimiser |
# | 1.3 | Adam | **Tanh** | Effect of changing the activation function |
#
# After running all three, compare their training curves side-by-side in TensorBoard (Section 5).

# %%
wandb.login()

 # prompts for API key if not already stored
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: royallineacademics (royallineacademics-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# 1.1  SGD + LeakyReLU — baseline experiment
from experiments.task01_cnn_sgd_leakyrelu import main as run_sgd_leakyrelu
run_sgd_leakyrelu()
# Out:
# Device: cuda
# GPU   : NVIDIA GeForce RTX 2080 Ti
#
# Loading CIFAR-10 …
# /usr/local/lib/python3.11/dist-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# CIFAR-10 ready | train: 40,000 | val: 10,000 | test: 10,000 | image size: 32×32
#
# Building SimpleCNN (LeakyReLU) …
# Total parameters: 1,276,682
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/wandb/run-20260401_021306-kat5p13z</code>
# Syncing run <strong><a href='https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/kat5p13z' target="_blank">Task01_CNN_SGD_LeakyReLU</a></strong> to <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab' target="_blank">https://wandb.ai/royallineacademics-/advanced-ai-lab</a>
#  View run at <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/kat5p13z' target="_blank">https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/kat5p13z</a>
# ══════════════════════════════════════════════════════════════
#   Experiment  : Task01_CNN_SGD_LeakyReLU
#   Device      : cuda  (NVIDIA GeForce RTX 2080 Ti)
#   Optimiser   : SGD  lr=0.0001
#   Epochs      : 200
#   Trainable   : 1,276,682 parameters
#   Split       : 70% train / 15% val / 15% test
#   W&B project : advanced-ai-lab  (view at https://wandb.ai)
# ══════════════════════════════════════════════════════════════
#   Epoch  1/200  |  Train  loss=2.2833  acc=13.3%  |  Val    loss=2.2222  acc=25.6%
#   Epoch  2/200  |  Train  loss=2.1826  acc=20.7%  |  Val    loss=2.0582  acc=30.4%
#   Epoch  3/200  |  Train  loss=2.0407  acc=25.3%  |  Val    loss=1.9214  acc=32.7%
#   Epoch  4/200  |  Train  loss=1.9400  acc=28.7%  |  Val    loss=1.8197  acc=35.7%
#   Epoch  5/200  |  Train  loss=1.8589  acc=31.2%  |  Val    loss=1.7351  acc=37.9%
#   Epoch  6/200  |  Train  loss=1.7996  acc=33.0%  |  Val    loss=1.6723  acc=39.4%
#   Epoch  7/200  |  Train  loss=1.7440  acc=34.6%  |  Val    loss=1.6063  acc=41.4%
#   Epoch  8/200  |  Train  loss=1.6985  acc=36.3%  |  Val    loss=1.5538  acc=43.3%
#   Epoch  9/200  |  Train  loss=1.6534  acc=38.0%  |  Val    loss=1.5186  acc=43.9%
#   Epoch 10/200  |  Train  loss=1.6268  acc=39.0%  |  Val    loss=1.4896  acc=45.0%
#   Epoch 11/200  |  Train  loss=1.6021  acc=40.1%  |  Val    loss=1.4565  acc=45.7%
#   Epoch 12/200  |  Train  loss=1.5731  acc=41.2%  |  Val    loss=1.4405  acc=46.9%
#   Epoch 13/200  |  Train  loss=1.5575  acc=41.8%  |  Val    loss=1.4084  acc=48.0%
#   Epoch 14/200  |  Train  loss=1.5362  acc=43.1%  |  Val    loss=1.3944  acc=48.6%
#   Epoch 15/200  |  Train  loss=1.5224  acc=43.5%  |  Val    loss=1.3758  acc=49.3%
#   Epoch 16/200  |  Train  loss=1.5026  acc=44.3%  |  Val    loss=1.3505  acc=50.3%
#   Epoch 17/200  |  Train  loss=1.4892  acc=44.8%  |  Val    loss=1.3379  acc=51.1%
#   Epoch 18/200  |  Train  loss=1.4671  acc=45.9%  |  Val    loss=1.3149  acc=52.0%
#   Epoch 19/200  |  Train  loss=1.4511  acc=46.5%  |  Val    loss=1.3011  acc=52.2%
#   Epoch 20/200  |  Train  loss=1.4413  acc=46.9%  |  Val    loss=1.2841  acc=53.0%
#   Epoch 21/200  |  Train  loss=1.4237  acc=47.5%  |  Val    loss=1.2553  acc=54.5%
#   Epoch 22/200  |  Train  loss=1.4058  acc=48.1%  |  Val    loss=1.2529  acc=54.5%
#   Epoch 23/200  |  Train  loss=1.3916  acc=48.7%  |  Val    loss=1.2243  acc=55.6%
#   Epoch 24/200  |  Train  loss=1.3822  acc=48.9%  |  Val    loss=1.2131  acc=56.3%
#   Epoch 25/200  |  Train  loss=1.3654  acc=50.2%  |  Val    loss=1.1958  acc=57.0%
#   Epoch 26/200  |  Train  loss=1.3525  acc=50.3%  |  Val    loss=1.1889  acc=57.0%
#   Epoch 27/200  |  Train  loss=1.3385  acc=50.8%  |  Val    loss=1.1762  acc=57.6%
#   Epoch 28/200  |  Train  loss=1.3338  acc=51.3%  |  Val    loss=1.1563  acc=58.4%
#   Epoch 29/200  |  Train  loss=1.3190  acc=52.0%  |  Val    loss=1.1446  acc=59.0%
#   Epoch 30/200  |  Train  loss=1.3027  acc=52.2%  |  Val    loss=1.1286  acc=59.6%
#   Epoch 31/200  |  Train  loss=1.2911  acc=52.8%  |  Val    loss=1.1156  acc=60.0%
#   Epoch 32/200  |  Train  loss=1.2739  acc=53.9%  |  Val    loss=1.1043  acc=60.4%
#   Epoch 33/200  |  Train  loss=1.2630  acc=54.2%  |  Val    loss=1.0986  acc=60.6%
#   Epoch 34/200  |  Train  loss=1.2585  acc=54.2%  |  Val    loss=1.0874  acc=60.9%
#   Epoch 35/200  |  Train  loss=1.2504  acc=54.3%  |  Val    loss=1.0891  acc=61.1%
#   Epoch 36/200  |  Train  loss=1.2410  acc=55.1%  |  Val    loss=1.0673  acc=61.8%
#   Epoch 37/200  |  Train  loss=1.2271  acc=55.3%  |  Val    loss=1.0609  acc=61.8%
#   Epoch 38/200  |  Train  loss=1.2215  acc=55.9%  |  Val    loss=1.0420  acc=62.7%
#   Epoch 39/200  |  Train  loss=1.2124  acc=56.4%  |  Val    loss=1.0314  acc=62.9%
#   Epoch 40/200  |  Train  loss=1.2055  acc=56.5%  |  Val    loss=1.0359  acc=62.5%
#   Epoch 41/200  |  Train  loss=1.1982  acc=56.6%  |  Val    loss=1.0302  acc=63.1%
#   Epoch 42/200  |  Train  loss=1.1908  acc=56.9%  |  Val    loss=1.0141  acc=63.3%
#   Epoch 43/200  |  Train  loss=1.1809  acc=57.3%  |  Val    loss=1.0073  acc=63.6%
#   Epoch 44/200  |  Train  loss=1.1762  acc=57.6%  |  Val    loss=1.0014  acc=63.9%
#   Epoch 45/200  |  Train  loss=1.1625  acc=58.1%  |  Val    loss=0.9998  acc=64.2%
#   Epoch 46/200  |  Train  loss=1.1582  acc=58.1%  |  Val    loss=0.9900  acc=64.3%
#   Epoch 47/200  |  Train  loss=1.1537  acc=58.4%  |  Val    loss=0.9799  acc=64.9%
#   Epoch 48/200  |  Train  loss=1.1473  acc=58.6%  |  Val    loss=0.9753  acc=64.9%
#   Epoch 49/200  |  Train  loss=1.1398  acc=59.1%  |  Val    loss=0.9713  acc=65.0%
#   Epoch 50/200  |  Train  loss=1.1330  acc=59.3%  |  Val    loss=0.9584  acc=65.6%
#   Epoch 197/200  |  Train  loss=0.7745  acc=72.7%  |  Val    loss=0.6539  acc=76.6%
#   Epoch 198/200  |  Train  loss=0.7712  acc=73.0%  |  Val    loss=0.6494  acc=76.7%
#   Epoch 199/200  |  Train  loss=0.7712  acc=72.9%  |  Val    loss=0.6385  acc=77.3%
#   Epoch 200/200  |  Train  loss=0.7661  acc=73.0%  |  Val    loss=0.6655  acc=76.0%
#
#   ✓ Restored best checkpoint  (val acc = 77.27%)
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>batch_loss</td><td>█▆▇▄▅▄▄▄▄▃▂▃▄▃▂▂▂▂▂▂▃▃▂▃▂▂▂▂▃▃▂▂▂▁▂▂▁▂▂▃</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▆▆▆▇▇▇▇▇▇▇███</td></tr><tr><td>train_accuracy</td><td>▁▁▂▃▄▄▄▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇█▇█████████████</td></tr><tr><td>train_loss</td><td>██▇▆▅▅▅▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▂▂▄▄▄▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇███████████████</td></tr><tr><td>val_loss</td><td>█▇▆▆▅▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>batch_loss</td><td>0.84107</td></tr><tr><td>best_val_accuracy</td><td>77.27</td></tr><tr><td>epoch</td><td>200</td></tr><tr><td>test_accuracy</td><td>77.25</td></tr><tr><td>test_loss</td><td>0.64944</td></tr><tr><td>train_accuracy</td><td>72.98</td></tr><tr><td>train_loss</td><td>0.76612</td></tr><tr><td>val_accuracy</td><td>75.98</td></tr><tr><td>val_loss</td><td>0.66552</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Task01_CNN_SGD_LeakyReLU</strong> at: <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/kat5p13z' target="_blank">https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/kat5p13z</a><br> View project at: <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab' target="_blank">https://wandb.ai/royallineacademics-/advanced-ai-lab</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code></code>
# ──────────────────────────────────────────────────────────────
#   ✓ Task01_CNN_SGD_LeakyReLU
#     Best Val Accuracy  : 77.27%
#     Final Test Accuracy: 77.25%
#     W&B dashboard      : https://wandb.ai
# ──────────────────────────────────────────────────────────────
#
# [Result] Experiment : Task01_CNN_SGD_LeakyReLU
# [Result] Best Validation Accuracy : 77.27%
# [Result] Optimiser: SGD | LR: 0.0001 | Activation: LeakyReLU

# %%
# 1.2  Adam + LeakyReLU — swap optimiser, keep everything else the same
from experiments.task01_cnn_adam_leakyrelu import main as run_adam_leakyrelu
run_adam_leakyrelu()
# Out:
# Device: cuda
# GPU   : NVIDIA GeForce RTX 2080 Ti
#
# Loading CIFAR-10 …
# /usr/local/lib/python3.11/dist-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# CIFAR-10 ready | train: 40,000 | val: 10,000 | test: 10,000 | image size: 32×32
#
# Building SimpleCNN (LeakyReLU) …
# Total parameters: 1,276,682
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/wandb/run-20260401_024632-l7skm0zw</code>
# Syncing run <strong><a href='https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/l7skm0zw' target="_blank">Task01_CNN_Adam_LeakyReLU</a></strong> to <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab' target="_blank">https://wandb.ai/royallineacademics-/advanced-ai-lab</a>
#  View run at <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/l7skm0zw' target="_blank">https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/l7skm0zw</a>
# ══════════════════════════════════════════════════════════════
#   Experiment  : Task01_CNN_Adam_LeakyReLU
#   Device      : cuda  (NVIDIA GeForce RTX 2080 Ti)
#   Optimiser   : Adam  lr=0.0001
#   Epochs      : 200
#   Trainable   : 1,276,682 parameters
#   Split       : 70% train / 15% val / 15% test
#   W&B project : advanced-ai-lab  (view at https://wandb.ai)
# ══════════════════════════════════════════════════════════════
#   Epoch  1/200  |  Train  loss=1.7169  acc=36.3%  |  Val    loss=1.3739  acc=49.9%
#   Epoch  2/200  |  Train  loss=1.4313  acc=47.5%  |  Val    loss=1.2405  acc=55.0%
#   Epoch  3/200  |  Train  loss=1.3304  acc=51.6%  |  Val    loss=1.1422  acc=58.7%
#   Epoch  4/200  |  Train  loss=1.2475  acc=54.9%  |  Val    loss=1.0588  acc=61.9%
#   Epoch  5/200  |  Train  loss=1.1893  acc=57.0%  |  Val    loss=0.9990  acc=63.8%
#   Epoch  6/200  |  Train  loss=1.1395  acc=59.0%  |  Val    loss=0.9586  acc=65.5%
#   Epoch  7/200  |  Train  loss=1.0965  acc=60.5%  |  Val    loss=0.9611  acc=65.5%
#   Epoch  8/200  |  Train  loss=1.0630  acc=61.9%  |  Val    loss=0.8903  acc=67.8%
#   Epoch  9/200  |  Train  loss=1.0323  acc=63.0%  |  Val    loss=0.8547  acc=69.7%
#   Epoch 10/200  |  Train  loss=1.0060  acc=64.3%  |  Val    loss=0.8453  acc=69.9%
#   Epoch 11/200  |  Train  loss=0.9898  acc=64.6%  |  Val    loss=0.8266  acc=71.0%
#   Epoch 12/200  |  Train  loss=0.9566  acc=66.1%  |  Val    loss=0.7963  acc=72.1%
#   Epoch 13/200  |  Train  loss=0.9454  acc=66.5%  |  Val    loss=0.8053  acc=71.9%
#   Epoch 14/200  |  Train  loss=0.9228  acc=67.3%  |  Val    loss=0.7700  acc=72.9%
#   Epoch 15/200  |  Train  loss=0.9091  acc=67.8%  |  Val    loss=0.7757  acc=73.0%
#   Epoch 16/200  |  Train  loss=0.8953  acc=68.3%  |  Val    loss=0.7382  acc=74.1%
#   Epoch 17/200  |  Train  loss=0.8764  acc=68.9%  |  Val    loss=0.7352  acc=74.1%
#   Epoch 18/200  |  Train  loss=0.8713  acc=69.2%  |  Val    loss=0.7196  acc=74.8%
#   Epoch 19/200  |  Train  loss=0.8508  acc=69.8%  |  Val    loss=0.7052  acc=75.0%
#   Epoch 20/200  |  Train  loss=0.8432  acc=70.1%  |  Val    loss=0.6931  acc=75.8%
#   Epoch 195/200  |  Train  loss=0.3692  acc=86.8%  |  Val    loss=0.4005  acc=86.6%
#   Epoch 196/200  |  Train  loss=0.3754  acc=86.8%  |  Val    loss=0.3983  acc=86.2%
#   Epoch 197/200  |  Train  loss=0.3720  acc=86.7%  |  Val    loss=0.4019  acc=86.3%
#   Epoch 198/200  |  Train  loss=0.3730  acc=86.9%  |  Val    loss=0.3972  acc=85.9%
#   Epoch 199/200  |  Train  loss=0.3713  acc=86.7%  |  Val    loss=0.3989  acc=86.1%
#   Epoch 200/200  |  Train  loss=0.3634  acc=87.1%  |  Val    loss=0.4035  acc=86.4%
#
#   ✓ Restored best checkpoint  (val acc = 86.63%)
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>batch_loss</td><td>██▇▆▄▅▄▄▃▃▃▃▃▃▂▃▂▁▃▃▂▂▂▂▃▁▂▁▁▁▃▂▂▂▂▂▂▁▁▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▄▄▄▄▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▇▇▇▇█████</td></tr><tr><td>train_accuracy</td><td>▁▁▂▃▄▅▅▅▅▅▆▆▆▆▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇██▇▇█████</td></tr><tr><td>train_loss</td><td>█▇▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇████████████████</td></tr><tr><td>val_loss</td><td>█▇▇▆▅▅▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>batch_loss</td><td>0.40151</td></tr><tr><td>best_val_accuracy</td><td>86.63</td></tr><tr><td>epoch</td><td>200</td></tr><tr><td>test_accuracy</td><td>85.7</td></tr><tr><td>test_loss</td><td>0.42414</td></tr><tr><td>train_accuracy</td><td>87.14</td></tr><tr><td>train_loss</td><td>0.36339</td></tr><tr><td>val_accuracy</td><td>86.36</td></tr><tr><td>val_loss</td><td>0.40348</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Task01_CNN_Adam_LeakyReLU</strong> at: <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/l7skm0zw' target="_blank">https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/l7skm0zw</a><br> View project at: <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab' target="_blank">https://wandb.ai/royallineacademics-/advanced-ai-lab</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code></code>
# ──────────────────────────────────────────────────────────────
#   ✓ Task01_CNN_Adam_LeakyReLU
#     Best Val Accuracy  : 86.63%
#     Final Test Accuracy: 85.70%
#     W&B dashboard      : https://wandb.ai
# ──────────────────────────────────────────────────────────────
#
# [Result] Experiment : Task01_CNN_Adam_LeakyReLU
# [Result] Best Test Accuracy : 86.63%
# [Result] Optimiser: Adam | LR: 0.0001 | Activation: LeakyReLU

# %%
# 1.3  Adam + Tanh — swap activation function (this is the required separate file)
from experiments.task01_cnn_adam_tanh import main as run_adam_tanh
run_adam_tanh()
# Out:
# Device: cuda
# GPU   : NVIDIA GeForce RTX 2080 Ti
#
# Loading CIFAR-10 …
# /usr/local/lib/python3.11/dist-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# CIFAR-10 ready | train: 40,000 | val: 10,000 | test: 10,000 | image size: 32×32
#
# Building SimpleCNN (Tanh) …
# Total parameters: 1,276,682
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/wandb/run-20260401_032006-s7trqckk</code>
# Syncing run <strong><a href='https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/s7trqckk' target="_blank">Task01_CNN_Adam_Tanh</a></strong> to <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab' target="_blank">https://wandb.ai/royallineacademics-/advanced-ai-lab</a>
#  View run at <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/s7trqckk' target="_blank">https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/s7trqckk</a>
# ══════════════════════════════════════════════════════════════
#   Experiment  : Task01_CNN_Adam_Tanh
#   Device      : cuda  (NVIDIA GeForce RTX 2080 Ti)
#   Optimiser   : Adam  lr=0.0001
#   Epochs      : 200
#   Trainable   : 1,276,682 parameters
#   Split       : 70% train / 15% val / 15% test
#   W&B project : advanced-ai-lab  (view at https://wandb.ai)
# ══════════════════════════════════════════════════════════════
#   Epoch  1/200  |  Train  loss=1.7105  acc=38.0%  |  Val    loss=1.3821  acc=49.8%
#   Epoch  2/200  |  Train  loss=1.4571  acc=47.0%  |  Val    loss=1.2679  acc=54.3%
#   Epoch  3/200  |  Train  loss=1.3613  acc=50.6%  |  Val    loss=1.1899  acc=56.6%
#   Epoch  4/200  |  Train  loss=1.2924  acc=53.6%  |  Val    loss=1.1164  acc=60.8%
#   Epoch  5/200  |  Train  loss=1.2359  acc=55.9%  |  Val    loss=1.0530  acc=62.5%
#   Epoch  6/200  |  Train  loss=1.1958  acc=57.0%  |  Val    loss=1.0231  acc=63.8%
#   Epoch  7/200  |  Train  loss=1.1646  acc=58.2%  |  Val    loss=1.0138  acc=63.5%
#   Epoch  8/200  |  Train  loss=1.1357  acc=59.2%  |  Val    loss=0.9862  acc=64.7%
#   Epoch  9/200  |  Train  loss=1.1061  acc=60.3%  |  Val    loss=0.9426  acc=66.6%
#   Epoch 10/200  |  Train  loss=1.0864  acc=60.9%  |  Val    loss=0.9150  acc=67.1%
#   Epoch 11/200  |  Train  loss=1.0681  acc=61.5%  |  Val    loss=0.9062  acc=67.3%
#   Epoch 12/200  |  Train  loss=1.0502  acc=62.6%  |  Val    loss=0.8918  acc=68.0%
#   Epoch 13/200  |  Train  loss=1.0307  acc=63.1%  |  Val    loss=0.8706  acc=68.8%
#   Epoch 14/200  |  Train  loss=1.0154  acc=63.8%  |  Val    loss=0.8560  acc=69.1%
#   Epoch 15/200  |  Train  loss=1.0007  acc=64.4%  |  Val    loss=0.8544  acc=69.0%
#   Epoch 16/200  |  Train  loss=0.9927  acc=64.6%  |  Val    loss=0.8383  acc=70.0%
#   Epoch 17/200  |  Train  loss=0.9709  acc=65.4%  |  Val    loss=0.8444  acc=69.8%
#   Epoch 192/200  |  Train  loss=0.4952  acc=82.5%  |  Val    loss=0.4941  acc=82.6%
#   Epoch 193/200  |  Train  loss=0.4935  acc=82.4%  |  Val    loss=0.4965  acc=83.0%
#   Epoch 194/200  |  Train  loss=0.4961  acc=82.3%  |  Val    loss=0.4927  acc=83.1%
#   Epoch 195/200  |  Train  loss=0.4944  acc=82.3%  |  Val    loss=0.5017  acc=82.8%
#   Epoch 196/200  |  Train  loss=0.4987  acc=82.4%  |  Val    loss=0.4928  acc=82.7%
#   Epoch 197/200  |  Train  loss=0.4949  acc=82.6%  |  Val    loss=0.4970  acc=82.6%
#   Epoch 198/200  |  Train  loss=0.4964  acc=82.4%  |  Val    loss=0.5002  acc=82.7%
#   Epoch 199/200  |  Train  loss=0.4934  acc=82.6%  |  Val    loss=0.4856  acc=83.3%
#   Epoch 200/200  |  Train  loss=0.4942  acc=82.6%  |  Val    loss=0.5018  acc=82.7%
#
#   ✓ Restored best checkpoint  (val acc = 83.28%)
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>batch_loss</td><td>█▇█▆▇▇▅▃▄▅▄▇▃▄▄▃▂▄▃▃▂▄▄▄▂▂▃▂▂▂▂▁▂▂▁▂▂▂▃▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>train_accuracy</td><td>▁▃▃▄▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇███████████████</td></tr><tr><td>train_loss</td><td>██▇▆▆▅▄▄▄▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▃▃▄▄▅▆▆▆▆▆▇▇▇▇▇▇▇▇█▇▇██▇███████████████</td></tr><tr><td>val_loss</td><td>█▆▅▅▅▄▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>batch_loss</td><td>0.52075</td></tr><tr><td>best_val_accuracy</td><td>83.28</td></tr><tr><td>epoch</td><td>200</td></tr><tr><td>test_accuracy</td><td>82.72</td></tr><tr><td>test_loss</td><td>0.50714</td></tr><tr><td>train_accuracy</td><td>82.58</td></tr><tr><td>train_loss</td><td>0.49418</td></tr><tr><td>val_accuracy</td><td>82.73</td></tr><tr><td>val_loss</td><td>0.50184</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Task01_CNN_Adam_Tanh</strong> at: <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/s7trqckk' target="_blank">https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/s7trqckk</a><br> View project at: <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab' target="_blank">https://wandb.ai/royallineacademics-/advanced-ai-lab</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code></code>
# ──────────────────────────────────────────────────────────────
#   ✓ Task01_CNN_Adam_Tanh
#     Best Val Accuracy  : 83.28%
#     Final Test Accuracy: 82.72%
#     W&B dashboard      : https://wandb.ai
# ──────────────────────────────────────────────────────────────
#
# [Result] Experiment : Task01_CNN_Adam_Tanh
# [Result] Best Test Accuracy : 83.28%
# [Result] Optimiser: Adam | LR: 0.0001 | Activation: Tanh

# %% [markdown]
# ---
# ## Section 2 — Task 0.2.1: AlexNet Transfer Learning on CIFAR-10
#
# AlexNet was pretrained on **ImageNet** (1,000 classes, 224×224 images).
# We adapt it for **CIFAR-10** (10 classes) two different ways:
#
# - **Fine-tuning** — all layers are updated → higher accuracy, more compute
# - **Feature extraction** — backbone is frozen, only the final layer trains → faster, slightly lower accuracy
#
# In both cases the original last layer `Linear(4096 → 1000)` is replaced with `Linear(4096 → 10)`.

# %%
# 2.1  AlexNet — Full Fine-Tuning (all layers updated)
from experiments.task02_alexnet_finetune import main as run_alexnet_finetune
run_alexnet_finetune()
# Out:
# Device: cuda
# GPU   : NVIDIA GeForce RTX 2080 Ti
#
# Loading CIFAR-10 (upscaled to 224×224 for AlexNet) …
# /usr/local/lib/python3.11/dist-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# CIFAR-10 ready | train: 40,000 | val: 10,000 | test: 10,000 | image size: 224×224
#
# Building AlexNet (pretrained=True, all layers trainable) …
# AlexNet (Fine-Tuning):
#   Total parameters     : 57,044,810
#   Trainable parameters : 57,044,810
#   Frozen parameters    : 0
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/wandb/run-20260401_094425-z1uwxyl9</code>
# Syncing run <strong><a href='https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/z1uwxyl9' target="_blank">Task02_AlexNet_FineTuning</a></strong> to <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab' target="_blank">https://wandb.ai/royallineacademics-/advanced-ai-lab</a>
#  View run at <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/z1uwxyl9' target="_blank">https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/z1uwxyl9</a>
# ══════════════════════════════════════════════════════════════
#   Experiment  : Task02_AlexNet_FineTuning
#   Device      : cuda  (NVIDIA GeForce RTX 2080 Ti)
#   Optimiser   : Adam  lr=0.0001
#   Epochs      : 50
#   Trainable   : 57,044,810 parameters
#   Split       : 70% train / 15% val / 15% test
#   W&B project : advanced-ai-lab  (view at https://wandb.ai)
# ══════════════════════════════════════════════════════════════
#   Epoch  1/50  |  Train  loss=0.6300  acc=78.1%  |  Val    loss=0.3933  acc=86.2%
#   Epoch  2/50  |  Train  loss=0.4076  acc=86.0%  |  Val    loss=0.3321  acc=88.6%
#   Epoch  3/50  |  Train  loss=0.3286  acc=88.6%  |  Val    loss=0.3573  acc=87.8%
#   Epoch  4/50  |  Train  loss=0.2833  acc=90.1%  |  Val    loss=0.3439  acc=88.4%
#   Epoch  5/50  |  Train  loss=0.2503  acc=91.3%  |  Val    loss=0.3003  acc=89.7%
#   Epoch  6/50  |  Train  loss=0.2231  acc=92.0%  |  Val    loss=0.2969  acc=89.7%
#   Epoch  7/50  |  Train  loss=0.2020  acc=93.0%  |  Val    loss=0.3003  acc=89.8%
#   Epoch  8/50  |  Train  loss=0.1824  acc=93.6%  |  Val    loss=0.3031  acc=90.1%
#   Epoch 38/50  |  Train  loss=0.0686  acc=97.8%  |  Val    loss=0.3498  acc=90.9%
#   Epoch 39/50  |  Train  loss=0.0658  acc=98.0%  |  Val    loss=0.3216  acc=91.6%
#   Epoch 40/50  |  Train  loss=0.0619  acc=98.0%  |  Val    loss=0.3853  acc=90.2%
#   Epoch 41/50  |  Train  loss=0.0630  acc=98.0%  |  Val    loss=0.3500  acc=91.4%
#   Epoch 42/50  |  Train  loss=0.0630  acc=98.0%  |  Val    loss=0.3559  acc=90.6%
#   Epoch 43/50  |  Train  loss=0.0570  acc=98.1%  |  Val    loss=0.4022  acc=90.6%
#   Epoch 44/50  |  Train  loss=0.0577  acc=98.1%  |  Val    loss=0.3697  acc=91.6%
#   Epoch 45/50  |  Train  loss=0.0670  acc=97.9%  |  Val    loss=0.3734  acc=91.1%
#   Epoch 46/50  |  Train  loss=0.0602  acc=98.0%  |  Val    loss=0.3594  acc=91.0%
#   Epoch 47/50  |  Train  loss=0.0603  acc=98.1%  |  Val    loss=0.3978  acc=91.0%
#   Epoch 48/50  |  Train  loss=0.0585  acc=98.1%  |  Val    loss=0.3267  acc=91.2%
#   Epoch 49/50  |  Train  loss=0.0581  acc=98.2%  |  Val    loss=0.3535  acc=90.8%
#   Epoch 50/50  |  Train  loss=0.0542  acc=98.3%  |  Val    loss=0.3692  acc=91.2%
#
#   ✓ Restored best checkpoint  (val acc = 91.62%)
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>batch_loss</td><td>██▃▇▂▃▄▂▂▄▂▂▂▃▃▂▃▃▂▁▁▃▁▁▁▃▁▂▁▁▁▁▂▁▂▁▄▁▁▂</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>train_accuracy</td><td>▁▄▅▅▆▆▆▇▇▇▇▇▇▇▇█▇███████████████████████</td></tr><tr><td>train_loss</td><td>█▅▄▄▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▃▄▆▆▆▄▇▇█▆▆▇█▇▇▇██▇██▇▇████▇█▆█▇▇▇▇▇██</td></tr><tr><td>val_loss</td><td>█▄▅▄▂▂▂▄▂▁▁▅▄▂▂▂▄▂▃▂▄▃▅▃▃▅▅▄▃▅█▅▇▅▅▆▅█▃▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>batch_loss</td><td>0.00598</td></tr><tr><td>best_val_accuracy</td><td>91.62</td></tr><tr><td>epoch</td><td>50</td></tr><tr><td>test_accuracy</td><td>91.25</td></tr><tr><td>test_loss</td><td>0.39366</td></tr><tr><td>train_accuracy</td><td>98.265</td></tr><tr><td>train_loss</td><td>0.05421</td></tr><tr><td>val_accuracy</td><td>91.24</td></tr><tr><td>val_loss</td><td>0.36918</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Task02_AlexNet_FineTuning</strong> at: <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/z1uwxyl9' target="_blank">https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/z1uwxyl9</a><br> View project at: <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab' target="_blank">https://wandb.ai/royallineacademics-/advanced-ai-lab</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code></code>
# ──────────────────────────────────────────────────────────────
#   ✓ Task02_AlexNet_FineTuning
#     Best Val Accuracy  : 91.62%
#     Final Test Accuracy: 91.25%
#     W&B dashboard      : https://wandb.ai
# ──────────────────────────────────────────────────────────────
#
# [Result] Experiment : Task02_AlexNet_FineTuning
# [Result] Best Test Accuracy : 91.62%
# [Result] Mode: Fine-Tuning (all layers updated)

# %%
# 2.2  AlexNet — Feature Extraction (backbone frozen, only FC head trains)
from experiments.task02_alexnet_feature_extraction import main as run_alexnet_features
run_alexnet_features()
# Out:
# Device: cuda
# GPU   : NVIDIA GeForce RTX 2080 Ti
#
# Loading CIFAR-10 (upscaled to 224×224 for AlexNet) …
# /usr/local/lib/python3.11/dist-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# CIFAR-10 ready | train: 40,000 | val: 10,000 | test: 10,000 | image size: 224×224
#
# Building AlexNet (backbone frozen, only FC head trains) …
# AlexNet (Feature Extraction):
#   Total parameters     : 57,044,810
#   Trainable parameters : 40,970
#   Frozen parameters    : 57,003,840
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/wandb/run-20260401_185403-dsbyduqb</code>
# Syncing run <strong><a href='https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/dsbyduqb' target="_blank">Task02_AlexNet_FeatureExtraction</a></strong> to <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab' target="_blank">https://wandb.ai/royallineacademics-/advanced-ai-lab</a>
#  View run at <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/dsbyduqb' target="_blank">https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/dsbyduqb</a>
# ══════════════════════════════════════════════════════════════
#   Experiment  : Task02_AlexNet_FeatureExtraction
#   Device      : cuda  (NVIDIA GeForce RTX 2080 Ti)
#   Optimiser   : Adam  lr=0.001
#   Epochs      : 50
#   Trainable   : 40,970 parameters
#   Split       : 70% train / 15% val / 15% test
#   W&B project : advanced-ai-lab  (view at https://wandb.ai)
# ══════════════════════════════════════════════════════════════
#   Epoch  1/50  |  Train  loss=0.8364  acc=71.1%  |  Val    loss=0.6093  acc=79.0%
#   Epoch  2/50  |  Train  loss=0.7598  acc=74.3%  |  Val    loss=0.7252  acc=76.5%
#   Epoch  3/50  |  Train  loss=0.7404  acc=75.1%  |  Val    loss=0.5958  acc=80.1%
#   Epoch  4/50  |  Train  loss=0.7398  acc=75.4%  |  Val    loss=0.6172  acc=79.8%
#   Epoch  5/50  |  Train  loss=0.7417  acc=75.4%  |  Val    loss=0.5844  acc=80.5%
#   Epoch  6/50  |  Train  loss=0.7268  acc=75.9%  |  Val    loss=0.6056  acc=80.1%
#   Epoch  7/50  |  Train  loss=0.7253  acc=76.1%  |  Val    loss=0.6131  acc=79.9%
#   Epoch  8/50  |  Train  loss=0.7312  acc=76.1%  |  Val    loss=0.5959  acc=80.5%
#   Epoch  9/50  |  Train  loss=0.7364  acc=76.0%  |  Val    loss=0.5891  acc=81.1%
#   Epoch 39/50  |  Train  loss=0.7337  acc=76.7%  |  Val    loss=0.6450  acc=80.0%
#   Epoch 40/50  |  Train  loss=0.7346  acc=76.8%  |  Val    loss=0.6608  acc=80.0%
#   Epoch 41/50  |  Train  loss=0.7371  acc=76.8%  |  Val    loss=0.6652  acc=79.7%
#   Epoch 42/50  |  Train  loss=0.7381  acc=76.9%  |  Val    loss=0.6279  acc=80.7%
#   Epoch 43/50  |  Train  loss=0.7336  acc=76.9%  |  Val    loss=0.6430  acc=80.1%
#   Epoch 44/50  |  Train  loss=0.7345  acc=76.7%  |  Val    loss=0.6107  acc=81.0%
#   Epoch 45/50  |  Train  loss=0.7340  acc=76.8%  |  Val    loss=0.6311  acc=80.4%
#   Epoch 46/50  |  Train  loss=0.7292  acc=76.7%  |  Val    loss=0.6459  acc=80.2%
#   Epoch 47/50  |  Train  loss=0.7193  acc=77.1%  |  Val    loss=0.6269  acc=80.7%
#   Epoch 48/50  |  Train  loss=0.7346  acc=76.9%  |  Val    loss=0.6483  acc=80.0%
#   Epoch 49/50  |  Train  loss=0.7334  acc=76.9%  |  Val    loss=0.6060  acc=81.2%
#   Epoch 50/50  |  Train  loss=0.7460  acc=76.7%  |  Val    loss=0.6196  acc=80.7%
#
#   ✓ Restored best checkpoint  (val acc = 81.53%)
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>batch_loss</td><td>▅▄▁▃▂▂▂▂▄▂▃▂▄▄▂▃▄▇▄▃▁▃▂▃▂▁▃▃▄▂▁▄▄▁▂▁▂█▃▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇██</td></tr><tr><td>train_accuracy</td><td>▁▅▆▆▆▇▇▇▇▇▇▇▇▇▇▇███▇███▇███▇████████████</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▁▂▂▂▂▂▂▁▂▂▂▂▂▂▂▁▂▂▂▂▂▂▃▂▂▂▂▂▂▂▂▂▁▂▃</td></tr><tr><td>val_accuracy</td><td>▄▁▆▆▇▆▇▇▇▅▇▆▆▇▆▆▅▅▇▆▇▇▅▆▅▇▇█▇▆▆▆▅▇▆▆▆▇▆▇</td></tr><tr><td>val_loss</td><td>▂█▂▃▁▃▂▂▁▅▃▃▂▄▂▅▄▃▄▅▃▂▅▃▂▃▄▃▂▄▃▄▅▅▃▃▄▄▃▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>batch_loss</td><td>0.39151</td></tr><tr><td>best_val_accuracy</td><td>81.53</td></tr><tr><td>epoch</td><td>50</td></tr><tr><td>test_accuracy</td><td>80.84</td></tr><tr><td>test_loss</td><td>0.60404</td></tr><tr><td>train_accuracy</td><td>76.65</td></tr><tr><td>train_loss</td><td>0.74598</td></tr><tr><td>val_accuracy</td><td>80.73</td></tr><tr><td>val_loss</td><td>0.61959</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Task02_AlexNet_FeatureExtraction</strong> at: <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/dsbyduqb' target="_blank">https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/dsbyduqb</a><br> View project at: <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab' target="_blank">https://wandb.ai/royallineacademics-/advanced-ai-lab</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code></code>
# ──────────────────────────────────────────────────────────────
#   ✓ Task02_AlexNet_FeatureExtraction
#     Best Val Accuracy  : 81.53%
#     Final Test Accuracy: 80.84%
#     W&B dashboard      : https://wandb.ai
# ──────────────────────────────────────────────────────────────
#
# [Result] Experiment : Task02_AlexNet_FeatureExtraction
# [Result] Best Test Accuracy : 81.53%
# [Result] Mode: Feature Extraction (backbone frozen)
#
# Why is feature extraction usually lower than fine-tuning?
#   AlexNet's backbone learned ImageNet patterns (1000 classes, high-res).
#   CIFAR-10 images are only 32×32 with 10 classes — a different distribution.
#   Because we cannot adjust the backbone, some feature mismatch remains.
#   Fine-tuning resolves this by updating every layer on CIFAR-10 data.

# %% [markdown]
# ---
# ## Section 3 — Task 0.2.2: Transfer Learning from MNIST → SVHN
#
# The cell below runs two stages automatically:
#
# **Stage 1** — Train a CNN from scratch on MNIST (clean handwritten digits, 28×28 grayscale).  Save the weights.
# **Stage 2** — Load those weights. Freeze the feature extractor. Fine-tune only the classifier on SVHN (real street-sign digits).
#
# SVHN images are converted to grayscale and resized to 28×28 so the **exact same architecture** works on both datasets.
#
# > **Grade-5 larger dataset**: set `"use_extra_data": True` in `config.py → SVHN_TRANSFER_CONFIG`
# > to also download the SVHN *extra* split (~531 K images, ~1 GB).

# %%
# 3.1  Stage 1: Train on MNIST  →  Stage 2: Transfer to SVHN
from experiments.task02_mnist_to_svhn import main as run_mnist_to_svhn
run_mnist_to_svhn()
# Out:
# Device: cuda
# GPU   : NVIDIA GeForce RTX 2080 Ti
#
# ══════════════════════════════════════════════════════════════
#   STAGE 1 — Train CNN on MNIST
# ══════════════════════════════════════════════════════════════
# MNIST ready | train: 48,000 | val: 12,000 | test: 10,000 | image size: 28×28 | channels: 1 (grayscale)
# MnistCNN parameters: 1,630,282
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: royallineacademics (royallineacademics-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/wandb/run-20260402_035113-5pmg1pbt</code>
# Syncing run <strong><a href='https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/5pmg1pbt' target="_blank">Task02_MNIST_Training</a></strong> to <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab' target="_blank">https://wandb.ai/royallineacademics-/advanced-ai-lab</a>
#  View run at <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/5pmg1pbt' target="_blank">https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/5pmg1pbt</a>
# ══════════════════════════════════════════════════════════════
#   Experiment  : Task02_MNIST_Training
#   Device      : cuda  (NVIDIA GeForce RTX 2080 Ti)
#   Optimiser   : Adam  lr=0.001
#   Epochs      : 100
#   Trainable   : 1,630,282 parameters
#   Split       : 70% train / 15% val / 15% test
#   W&B project : advanced-ai-lab  (view at https://wandb.ai)
# ══════════════════════════════════════════════════════════════
#   Epoch  1/100  |  Train  loss=0.1839  acc=94.1%  |  Val    loss=0.0748  acc=97.6%
#   Epoch 89/100  |  Train  loss=0.0082  acc=99.8%  |  Val    loss=0.0327  acc=99.4%
#   Epoch 90/100  |  Train  loss=0.0044  acc=99.8%  |  Val    loss=0.0310  acc=99.5%
#   Epoch 91/100  |  Train  loss=0.0059  acc=99.8%  |  Val    loss=0.0393  acc=99.4%
#   Epoch 92/100  |  Train  loss=0.0054  acc=99.8%  |  Val    loss=0.0383  acc=99.4%
#   Epoch 93/100  |  Train  loss=0.0050  acc=99.8%  |  Val    loss=0.0367  acc=99.5%
#   Epoch 94/100  |  Train  loss=0.0070  acc=99.8%  |  Val    loss=0.0408  acc=99.4%
#   Epoch 95/100  |  Train  loss=0.0071  acc=99.8%  |  Val    loss=0.0359  acc=99.5%
#   Epoch 96/100  |  Train  loss=0.0064  acc=99.8%  |  Val    loss=0.0427  acc=99.4%
#   Epoch 97/100  |  Train  loss=0.0063  acc=99.8%  |  Val    loss=0.0349  acc=99.4%
#   Epoch 98/100  |  Train  loss=0.0074  acc=99.8%  |  Val    loss=0.0421  acc=99.4%
#   Epoch 99/100  |  Train  loss=0.0062  acc=99.8%  |  Val    loss=0.0376  acc=99.4%
#   Epoch 100/100  |  Train  loss=0.0063  acc=99.8%  |  Val    loss=0.0328  acc=99.5%
#
#   ✓ Restored best checkpoint  (val acc = 99.49%)
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>batch_loss</td><td>▂█▂▂▂▁▁▁▁▁▁▂▁▁▁█▁▁▁▁▃▁▁▁▁▁▁▁▁▁▁▁▁▁▅▁▄▁▁▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▃▃▃▃▄▄▄▄▅▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇███</td></tr><tr><td>train_accuracy</td><td>▁▆▆▇▇▇▇▇▇▇██████████████████████████████</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▅▆▇▇▇▇▇▇▇▇▇▇▇█▇████▇▇▇▇▇▇▇███▇████████</td></tr><tr><td>val_loss</td><td>▆█▄▃▂▂▁▂▁▂▁▂▂▂▄▂▃▂▃▂▃▂▂▃▅▂▃▃▁▂▃▂▂▄▃▃▅▂▅▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>batch_loss</td><td>0.00033</td></tr><tr><td>best_val_accuracy</td><td>99.49167</td></tr><tr><td>epoch</td><td>100</td></tr><tr><td>test_accuracy</td><td>99.3</td></tr><tr><td>test_loss</td><td>0.03068</td></tr><tr><td>train_accuracy</td><td>99.82708</td></tr><tr><td>train_loss</td><td>0.00633</td></tr><tr><td>val_accuracy</td><td>99.45833</td></tr><tr><td>val_loss</td><td>0.03277</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Task02_MNIST_Training</strong> at: <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/5pmg1pbt' target="_blank">https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/5pmg1pbt</a><br> View project at: <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab' target="_blank">https://wandb.ai/royallineacademics-/advanced-ai-lab</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code></code>
# ──────────────────────────────────────────────────────────────
#   ✓ Task02_MNIST_Training
#     Best Val Accuracy  : 99.49%
#     Final Test Accuracy: 99.30%
#     W&B dashboard      : https://wandb.ai
# ──────────────────────────────────────────────────────────────
#
# Checkpoint saved → /Labs/Lab0/checkpoints/mnist_cnn.pth
# [Stage 1 Result] MNIST Test Accuracy : 99.49%
#
#
# ══════════════════════════════════════════════════════════════
#   STAGE 2 — Transfer CNN from MNIST to SVHN
# ══════════════════════════════════════════════════════════════
# Downloading SVHN 'extra' split (~1 GB) for Grade-5 larger-dataset requirement …
# Combined train set size: 604,388 images
# SVHN (grayscale) ready | train: 483,511 | val: 120,877 | test: 26,032 | image size: 28×28 | channels: 1 | extra split: True
# Checkpoint loaded ← /Labs/Lab0/checkpoints/mnist_cnn.pth
# Feature extractor FROZEN — only the classifier will be updated.
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/wandb/run-20260402_040650-y6iogf6d</code>
# Syncing run <strong><a href='https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/y6iogf6d' target="_blank">Task02_SVHN_Transfer</a></strong> to <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab' target="_blank">https://wandb.ai/royallineacademics-/advanced-ai-lab</a>
#  View run at <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/y6iogf6d' target="_blank">https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/y6iogf6d</a>
# ══════════════════════════════════════════════════════════════
#   Experiment  : Task02_SVHN_Transfer
#   Device      : cuda  (NVIDIA GeForce RTX 2080 Ti)
#   Optimiser   : Adam  lr=0.0001
#   Epochs      : 100
#   Trainable   : 1,611,274 parameters
#   Split       : 70% train / 15% val / 15% test
#   W&B project : advanced-ai-lab  (view at https://wandb.ai)
# ══════════════════════════════════════════════════════════════
#   Epoch  1/100  |  Train  loss=1.8643  acc=52.3%  |  Val    loss=0.7836  acc=79.9%
#   Epoch  2/100  |  Train  loss=0.8900  acc=71.8%  |  Val    loss=0.5795  acc=85.0%
#   Epoch  3/100  |  Train  loss=0.7499  acc=76.4%  |  Val    loss=0.5093  acc=86.7%
#   Epoch  4/100  |  Train  loss=0.6822  acc=78.6%  |  Val    loss=0.4545  acc=88.0%
#   Epoch  5/100  |  Train  loss=0.6364  acc=80.0%  |  Val    loss=0.4245  acc=88.6%
#   Epoch  6/100  |  Train  loss=0.6032  acc=81.0%  |  Val    loss=0.4044  acc=89.1%
#   Epoch  7/100  |  Train  loss=0.5771  acc=81.9%  |  Val    loss=0.3948  acc=89.4%
#   Epoch  8/100  |  Train  loss=0.5579  acc=82.4%  |  Val    loss=0.3761  acc=90.0%
#   Epoch  9/100  |  Train  loss=0.5416  acc=83.0%  |  Val    loss=0.3644  acc=90.2%
#   Epoch 10/100  |  Train  loss=0.5259  acc=83.5%  |  Val    loss=0.3525  acc=90.5%
#   Epoch 11/100  |  Train  loss=0.5135  acc=83.9%  |  Val    loss=0.3402  acc=90.7%
#   Epoch 12/100  |  Train  loss=0.5036  acc=84.2%  |  Val    loss=0.3393  acc=90.8%
#   Epoch 71/100  |  Train  loss=0.3320  acc=89.6%  |  Val    loss=0.2325  acc=93.8%
#   Epoch 72/100  |  Train  loss=0.3293  acc=89.7%  |  Val    loss=0.2326  acc=93.8%
#   Epoch 73/100  |  Train  loss=0.3280  acc=89.8%  |  Val    loss=0.2345  acc=93.7%
#   Epoch 74/100  |  Train  loss=0.3267  acc=89.8%  |  Val    loss=0.2313  acc=93.8%
#   Epoch 75/100  |  Train  loss=0.3268  acc=89.8%  |  Val    loss=0.2295  acc=93.9%
#   Epoch 76/100  |  Train  loss=0.3267  acc=89.8%  |  Val    loss=0.2299  acc=93.9%
#   Epoch 77/100  |  Train  loss=0.3250  acc=89.8%  |  Val    loss=0.2324  acc=93.8%
#   Epoch 78/100  |  Train  loss=0.3254  acc=89.8%  |  Val    loss=0.2299  acc=93.9%
#   Epoch 79/100  |  Train  loss=0.3234  acc=89.8%  |  Val    loss=0.2315  acc=93.8%
#   Epoch 80/100  |  Train  loss=0.3244  acc=89.8%  |  Val    loss=0.2280  acc=93.9%
#   Epoch 81/100  |  Train  loss=0.3209  acc=89.9%  |  Val    loss=0.2281  acc=93.8%
#   Epoch 82/100  |  Train  loss=0.3229  acc=89.9%  |  Val    loss=0.2298  acc=93.8%
#   Epoch 83/100  |  Train  loss=0.3213  acc=89.9%  |  Val    loss=0.2308  acc=93.9%
#   Epoch 84/100  |  Train  loss=0.3202  acc=89.9%  |  Val    loss=0.2294  acc=93.9%
#   Epoch 85/100  |  Train  loss=0.3183  acc=90.0%  |  Val    loss=0.2267  acc=94.0%
#   Epoch 86/100  |  Train  loss=0.3186  acc=90.0%  |  Val    loss=0.2277  acc=93.9%
#   Epoch 87/100  |  Train  loss=0.3171  acc=90.1%  |  Val    loss=0.2275  acc=93.9%
#   Epoch 88/100  |  Train  loss=0.3182  acc=90.0%  |  Val    loss=0.2290  acc=93.9%
#   Epoch 89/100  |  Train  loss=0.3167  acc=90.0%  |  Val    loss=0.2262  acc=94.0%
#   Epoch 90/100  |  Train  loss=0.3155  acc=90.1%  |  Val    loss=0.2283  acc=93.9%
#   Epoch 91/100  |  Train  loss=0.3148  acc=90.1%  |  Val    loss=0.2277  acc=93.9%
#   Epoch 92/100  |  Train  loss=0.3132  acc=90.2%  |  Val    loss=0.2264  acc=93.9%
#   Epoch 93/100  |  Train  loss=0.3130  acc=90.2%  |  Val    loss=0.2236  acc=94.0%
#   Epoch 94/100  |  Train  loss=0.3128  acc=90.2%  |  Val    loss=0.2229  acc=94.0%
#   Epoch 95/100  |  Train  loss=0.3118  acc=90.2%  |  Val    loss=0.2238  acc=94.0%
#   Epoch  96 [train]:  34%|███▍      | 2555/7555 [00:24<00:49, 101.57it/s, acc=90.3%, loss=0.3104]

# %% [markdown]
# ---
# ## Section 4 — Grade 5: Two Transformer Models on CIFAR-10
#
# Runs **ViT-B/16** and **Swin-T** back-to-back, both pretrained on ImageNet and fine-tuned for CIFAR-10.
#
# - **ViT-B/16** — splits image into 16×16 patches, applies global self-attention across all patches
# - **Swin-T** — uses local shifted-window attention in a hierarchical layout, more memory-efficient
#
# > ⚠ GPU strongly recommended. On CPU, reduce `"epochs"` in `config.py` (e.g. to `1`) to save time.

# %%
# 4.1  ViT-B/16 + Swin-T on CIFAR-10
from experiments.grade5_transformers_cifar10 import main as run_transformers
run_transformers()
# Out:
# Device: cuda
# GPU   : NVIDIA GeForce RTX 2080 Ti
#
# Loading CIFAR-10 (224×224, batch=16) …
# /usr/local/lib/python3.11/dist-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# CIFAR-10 ready | train: 40,000 | val: 10,000 | test: 10,000 | image size: 224×224
#
# Building ViT-B/16 (pretrained on ImageNet) …
# ViT-B/16:
#   Total parameters     : 85,806,346
#   Trainable parameters : 85,806,346
#
# ▶▶▶  Starting transformer experiment: Grade5_ViT_B16_CIFAR10
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: royallineacademics (royallineacademics-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/wandb/run-20260402_202932-r9ez4n0t</code>
# Syncing run <strong><a href='https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/r9ez4n0t' target="_blank">Grade5_ViT_B16_CIFAR10</a></strong> to <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab' target="_blank">https://wandb.ai/royallineacademics-/advanced-ai-lab</a>
#  View run at <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/r9ez4n0t' target="_blank">https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/r9ez4n0t</a>
# ══════════════════════════════════════════════════════════════
#   Experiment  : Grade5_ViT_B16_CIFAR10
#   Device      : cuda  (NVIDIA GeForce RTX 2080 Ti)
#   Optimiser   : Adam  lr=0.0001
#   Epochs      : 5
#   Trainable   : 85,806,346 parameters
#   Split       : 70% train / 15% val / 15% test
#   W&B project : advanced-ai-lab  (view at https://wandb.ai)
# ══════════════════════════════════════════════════════════════
#   Epoch   1 [train]:  85%|████████▍ | 2117/2500 [07:28<01:21,  4.70it/s, acc=88.1%, loss=0.3602]

# %% [markdown]
# ---
# ## Section 5 — Weights & Biases: View All Results
#
# All experiments automatically log to **https://wandb.ai** — no local server needed, no port forwarding required.
#
# ### First-time setup (run once)
# Run cell 17 below — it installs wandb (if missing) and logs you in with your API key.
# Get your key at: **https://wandb.ai/authorize**
#
# ### Viewing results
# Open **https://wandb.ai** in any browser — all runs are grouped under project **`advanced-ai-lab`**.
# Use the **Charts** panel to compare training curves from all experiments side-by-side.
#
# > To rename the project, change `WANDB_PROJECT` in `config.py`.

# %%
# 5.1  Log in to Weights & Biases (run once)
# This installs wandb if needed, then opens a login prompt.
# Paste your API key from https://wandb.ai/authorize when prompted.

import subprocess, sys

# Install wandb if not already present
subprocess.run([sys.executable, "-m", "pip", "install", "-q", "wandb"], check=True)

# %% [markdown]
# # Advanced AI Lab — Main Notebook
#
# This is the **single entry point** for all lab experiments.
# Run the cells top-to-bottom in each section you need.
# All heavy logic lives in the project files — this notebook just calls them.
#
# | Section | Task |
# |---|---|
# | 0 — Setup | Check GPU, verify imports |
# | 1 — Task 0.1 | Simple CNN: SGD vs Adam vs Tanh |
# | 2 — Task 0.2.1 | AlexNet transfer learning on CIFAR-10 |
# | 3 — Task 0.2.2 | MNIST → SVHN transfer learning |
# | 4 — Grade 5 | ViT-B/16 + Swin Transformer on CIFAR-10 |
# | 5 — TensorBoard | Visualise all experiment results |

# %% [markdown]
# ---
# ## Section 0 — Setup
#
# Run this cell once before anything else.
# It checks that PyTorch is installed and shows whether a GPU is available.

# %%
import sys
import os

# Make sure the project root is on the Python path so all imports work
project_root = "/Labs/Lab0"
sys.path.insert(0, project_root)

import torch
import config

import wandb


print("=" * 50)
print(f"PyTorch version : {torch.__version__}")
print(f"CUDA available  : {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU name        : {torch.cuda.get_device_name(0)}")
print(f"Device in use   : {config.DEVICE}")
print("=" * 50)
print("\nAll project modules are ready.")
print("Run any section below to start an experiment.")
# Out:
# ==================================================
# PyTorch version : 2.11.0+cu130
# CUDA available  : True
# GPU name        : NVIDIA GeForce RTX 2080 Ti
# Device in use   : cuda
# ==================================================
#
# All project modules are ready.
# Run any section below to start an experiment.

# %% [markdown]
# ---
# ## Section 1 — Task 0.1: Simple CNN on CIFAR-10
#
# Three experiments with the **same CNN architecture**, changing only one thing at a time:
#
# | Cell | Optimiser | Activation | What we learn |
# |---|---|---|---|
# | 1.1 | SGD | LeakyReLU | Baseline |
# | 1.2 | **Adam** | LeakyReLU | Effect of a better optimiser |
# | 1.3 | Adam | **Tanh** | Effect of changing the activation function |
#
# After running all three, compare their training curves side-by-side in TensorBoard (Section 5).

# %%
wandb.login(relogin=True)
wandb.init(project="Lab0")

 # prompts for API key if not already stored
# Out:
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">light-moon-3</strong> at: <a href='https://wandb.ai/royallineacademics-/Lab0/runs/zzzu8rjj' target="_blank">https://wandb.ai/royallineacademics-/Lab0/runs/zzzu8rjj</a><br> View project at: <a href='https://wandb.ai/royallineacademics-/Lab0' target="_blank">https://wandb.ai/royallineacademics-/Lab0</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code></code>
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/wandb/run-20260331_173741-xg5zvq6t</code>
# Syncing run <strong><a href='https://wandb.ai/royallineacademics-/Lab0/runs/xg5zvq6t' target="_blank">radiant-energy-4</a></strong> to <a href='https://wandb.ai/royallineacademics-/Lab0' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/royallineacademics-/Lab0' target="_blank">https://wandb.ai/royallineacademics-/Lab0</a>
#  View run at <a href='https://wandb.ai/royallineacademics-/Lab0/runs/xg5zvq6t' target="_blank">https://wandb.ai/royallineacademics-/Lab0/runs/xg5zvq6t</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/royallineacademics-/Lab0/runs/xg5zvq6t?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
# 1.1  SGD + LeakyReLU — baseline experiment
from experiments.task01_cnn_sgd_leakyrelu import main as run_sgd_leakyrelu
run_sgd_leakyrelu()
# Out:
# Device: cuda
# GPU   : NVIDIA GeForce RTX 2080 Ti
#
# Loading CIFAR-10 …
# /usr/local/lib/python3.11/dist-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# CIFAR-10 ready | train: 40,000 | val: 10,000 | test: 10,000 | image size: 32×32
#
# Building SimpleCNN (LeakyReLU) …
# Total parameters: 1,276,682
# Finishing previous runs because reinit is set to True.
#  View run <strong style="color:#cdcd00">radiant-energy-4</strong> at: <a href='https://wandb.ai/royallineacademics-/Lab0/runs/xg5zvq6t' target="_blank">https://wandb.ai/royallineacademics-/Lab0/runs/xg5zvq6t</a><br> View project at: <a href='https://wandb.ai/royallineacademics-/Lab0' target="_blank">https://wandb.ai/royallineacademics-/Lab0</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code></code>
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/wandb/run-20260331_173753-0gi2zyq8</code>
# Syncing run <strong><a href='https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/0gi2zyq8' target="_blank">Task01_CNN_SGD_LeakyReLU</a></strong> to <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab' target="_blank">https://wandb.ai/royallineacademics-/advanced-ai-lab</a>
#  View run at <a href='https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/0gi2zyq8' target="_blank">https://wandb.ai/royallineacademics-/advanced-ai-lab/runs/0gi2zyq8</a>
# ══════════════════════════════════════════════════════════════
#   Experiment  : Task01_CNN_SGD_LeakyReLU
#   Device      : cuda  (NVIDIA GeForce RTX 2080 Ti)
#   Optimiser   : SGD  lr=0.0001
#   Epochs      : 100
#   Trainable   : 1,276,682 parameters
#   Split       : 70% train / 15% val / 15% test
#   W&B project : advanced-ai-lab  (view at https://wandb.ai)
# ══════════════════════════════════════════════════════════════
#   Epoch  1/100  |  Train  loss=2.2827  acc=13.7%  |  Val    loss=2.2245  acc=25.4%
#   Epoch  2/100  |  Train  loss=2.1883  acc=21.0%  |  Val    loss=2.0772  acc=26.3%
#   Epoch  3/100  |  Train  loss=2.0586  acc=24.7%  |  Val    loss=1.9481  acc=30.3%
#   Epoch  4/100  |  Train  loss=1.9619  acc=28.0%  |  Val    loss=1.8384  acc=35.0%
#   Epoch  5/100  |  Train  loss=1.8740  acc=31.2%  |  Val    loss=1.7437  acc=37.5%
#   Epoch  6/100  |  Train  loss=1.8051  acc=32.8%  |  Val    loss=1.6698  acc=39.9%
#   Epoch  7/100  |  Train  loss=1.7431  acc=35.0%  |  Val    loss=1.5950  acc=42.3%
#   Epoch  8/100  |  Train  loss=1.6973  acc=36.7%  |  Val    loss=1.5464  acc=43.7%
#   Epoch  9/100  |  Train  loss=1.6534  acc=38.5%  |  Val    loss=1.5063  acc=44.9%
#   Epoch 10/100  |  Train  loss=1.6220  acc=39.5%  |  Val    loss=1.4807  acc=45.9%
#   Epoch 11/100  |  Train  loss=1.5957  acc=40.8%  |  Val    loss=1.4499  acc=47.2%
#   Epoch 12/100  |  Train  loss=1.5743  acc=41.4%  |  Val    loss=1.4309  acc=47.6%
#   Epoch 13/100  |  Train  loss=1.5522  acc=42.5%  |  Val    loss=1.4007  acc=49.0%
#   Epoch 14/100  |  Train  loss=1.5347  acc=43.0%  |  Val    loss=1.3789  acc=50.2%
#   Epoch 15/100  |  Train  loss=1.5121  acc=44.0%  |  Val    loss=1.3525  acc=51.4%
#   Epoch 16/100  |  Train  loss=1.4958  acc=44.9%  |  Val    loss=1.3406  acc=51.7%
#   Epoch 17/100  |  Train  loss=1.4799  acc=45.4%  |  Val    loss=1.3213  acc=52.0%
#   Epoch 18/100  |  Train  loss=1.4630  acc=46.0%  |  Val    loss=1.3007  acc=53.0%
#   Epoch 19/100  |  Train  loss=1.4435  acc=46.9%  |  Val    loss=1.2846  acc=53.5%
#   Epoch 20/100  |  Train  loss=1.4235  acc=47.6%  |  Val    loss=1.2577  acc=54.5%
#   Epoch 21/100  |  Train  loss=1.4081  acc=48.3%  |  Val    loss=1.2420  acc=55.1%
#   Epoch 22/100  |  Train  loss=1.3964  acc=48.7%  |  Val    loss=1.2222  acc=55.9%
#   Epoch 23/100  |  Train  loss=1.3798  acc=49.8%  |  Val    loss=1.2063  acc=56.7%
#   Epoch 24/100  |  Train  loss=1.3596  acc=50.0%  |  Val    loss=1.1862  acc=57.3%
#   Epoch 25/100  |  Train  loss=1.3448  acc=51.0%  |  Val    loss=1.1807  acc=58.1%
#   Epoch 26/100  |  Train  loss=1.3348  acc=51.5%  |  Val    loss=1.1670  acc=58.2%
#   Epoch 27/100  |  Train  loss=1.3207  acc=51.9%  |  Val    loss=1.1398  acc=59.0%
#   Epoch 28/100  |  Train  loss=1.3083  acc=52.2%  |  Val    loss=1.1254  acc=59.6%
#   Epoch 29/100  |  Train  loss=1.2892  acc=52.9%  |  Val    loss=1.1188  acc=59.9%
#   Epoch 30/100  |  Train  loss=1.2813  acc=53.5%  |  Val    loss=1.0994  acc=60.7%
#   Epoch 31/100  |  Train  loss=1.2678  acc=53.8%  |  Val    loss=1.0914  acc=60.8%
#   Epoch 32/100  |  Train  loss=1.2552  acc=54.5%  |  Val    loss=1.0809  acc=61.4%
#   Epoch 33/100  |  Train  loss=1.2501  acc=54.8%  |  Val    loss=1.0796  acc=61.0%
#   Epoch 34/100  |  Train  loss=1.2436  acc=54.9%  |  Val    loss=1.0562  acc=62.2%
#   Epoch 35/100  |  Train  loss=1.2274  acc=55.7%  |  Val    loss=1.0579  acc=61.9%
#   Epoch 36/100  |  Train  loss=1.2212  acc=56.0%  |  Val    loss=1.0440  acc=62.2%
#   Epoch 37/100  |  Train  loss=1.2106  acc=56.4%  |  Val    loss=1.0354  acc=62.7%
#   Epoch 38/100  |  Train  loss=1.2038  acc=56.5%  |  Val    loss=1.0314  acc=62.7%
#   Epoch 39/100  |  Train  loss=1.1933  acc=56.9%  |  Val    loss=1.0194  acc=63.6%
#   Epoch 40/100  |  Train  loss=1.1860  acc=57.3%  |  Val    loss=1.0183  acc=63.3%
#   Epoch 41/100  |  Train  loss=1.1783  acc=57.4%  |  Val    loss=1.0135  acc=63.6%
#   Epoch 42/100  |  Train  loss=1.1723  acc=57.7%  |  Val    loss=1.0074  acc=63.8%
#   Epoch 43/100  |  Train  loss=1.1691  acc=57.8%  |  Val    loss=0.9987  acc=64.4%
#   Epoch 44/100  |  Train  loss=1.1590  acc=58.2%  |  Val    loss=0.9856  acc=64.7%
#   Epoch 45/100  |  Train  loss=1.1478  acc=58.6%  |  Val    loss=0.9789  acc=65.0%
#   Epoch 46/100  |  Train  loss=1.1427  acc=58.9%  |  Val    loss=0.9720  acc=64.9%
#   Epoch 47/100  |  Train  loss=1.1357  acc=59.0%  |  Val    loss=0.9874  acc=64.5%
#   Epoch 48/100  |  Train  loss=1.1290  acc=59.3%  |  Val    loss=0.9598  acc=65.3%
#   Epoch 49/100  |  Train  loss=1.1287  acc=59.4%  |  Val    loss=0.9514  acc=65.7%
#   Epoch 50/100  |  Train  loss=1.1112  acc=60.2%  |  Val    loss=0.9535  acc=65.7%
#   Epoch 51/100  |  Train  loss=1.1120  acc=59.9%  |  Val    loss=0.9543  acc=65.4%
#   Epoch 52/100  |  Train  loss=1.1101  acc=60.0%  |  Val    loss=0.9483  acc=66.5%
#   Epoch 53/100  |  Train  loss=1.1010  acc=60.3%  |  Val    loss=0.9421  acc=66.1%
#   Epoch 54/100  |  Train  loss=1.0965  acc=60.9%  |  Val    loss=0.9233  acc=66.7%
#   Epoch 55/100  |  Train  loss=1.0921  acc=60.8%  |  Val    loss=0.9159  acc=67.2%
#   Epoch 56/100  |  Train  loss=1.0845  acc=61.2%  |  Val    loss=0.9318  acc=66.4%
#   Epoch 57/100  |  Train  loss=1.0813  acc=61.3%  |  Val    loss=0.9174  acc=67.3%
#   Epoch 58/100  |  Train  loss=1.0757  acc=61.3%  |  Val    loss=0.9301  acc=66.6%
#   Epoch 59/100  |  Train  loss=1.0739  acc=61.4%  |  Val    loss=0.9052  acc=67.5%
#   Epoch 60/100  |  Train  loss=1.0692  acc=61.5%  |  Val    loss=0.9026  acc=67.7%
#   Epoch 61/100  |  Train  loss=1.0679  acc=61.9%  |  Val    loss=0.9071  acc=67.5%
#   Epoch 62/100  |  Train  loss=1.0562  acc=62.1%  |  Val    loss=0.8949  acc=67.9%
#   Epoch 63/100  |  Train  loss=1.0550  acc=62.3%  |  Val    loss=0.8837  acc=68.4%
#   Epoch 64/100  |  Train  loss=1.0495  acc=62.2%  |  Val    loss=0.8787  acc=68.7%
#   Epoch 65/100  |  Train  loss=1.0474  acc=62.9%  |  Val    loss=0.8821  acc=68.4%
#   Epoch 66/100  |  Train  loss=1.0437  acc=62.5%  |  Val    loss=0.8676  acc=69.1%
#   Epoch 67/100  |  Train  loss=1.0407  acc=62.6%  |  Val    loss=0.8685  acc=68.9%
#   Epoch 68/100  |  Train  loss=1.0340  acc=63.2%  |  Val    loss=0.8742  acc=68.5%
#   Epoch 69/100  |  Train  loss=1.0319  acc=63.3%  |  Val    loss=0.8670  acc=69.3%
#   Epoch 70/100  |  Train  loss=1.0245  acc=63.2%  |  Val    loss=0.8656  acc=69.3%
#   Epoch 71/100  |  Train  loss=1.0186  acc=63.4%  |  Val    loss=0.8603  acc=69.5%
#   Epoch 72/100  |  Train  loss=1.0186  acc=63.4%  |  Val    loss=0.8557  acc=69.4%
#   Epoch 73/100  |  Train  loss=1.0156  acc=63.6%  |  Val    loss=0.8500  acc=69.8%
#   Epoch 74/100  |  Train  loss=1.0089  acc=64.0%  |  Val    loss=0.8493  acc=69.8%
#   Epoch 75/100  |  Train  loss=1.0045  acc=64.1%  |  Val    loss=0.8398  acc=70.5%
#   Epoch 76/100  |  Train  loss=1.0031  acc=64.2%  |  Val    loss=0.8567  acc=69.3%
#   Epoch 77/100  |  Train  loss=1.0019  acc=64.3%  |  Val    loss=0.8428  acc=69.8%
#   Epoch 78/100  |  Train  loss=0.9963  acc=64.2%  |  Val    loss=0.8369  acc=70.4%
#   Epoch 79/100  |  Train  loss=0.9884  acc=64.8%  |  Val    loss=0.8304  acc=70.5%
#   Epoch 80/100  |  Train  loss=0.9889  acc=64.9%  |  Val    loss=0.8295  acc=70.6%
#   Epoch 81/100  |  Train  loss=0.9832  acc=65.3%  |  Val    loss=0.8286  acc=70.3%
#   Epoch 82/100  |  Train  loss=0.9842  acc=65.0%  |  Val    loss=0.8215  acc=70.8%
#   Epoch 83/100  |  Train  loss=0.9816  acc=64.9%  |  Val    loss=0.8291  acc=70.7%
#   Epoch 84/100  |  Train  loss=0.9740  acc=65.2%  |  Val    loss=0.8190  acc=70.8%
#   Epoch 85/100  |  Train  loss=0.9747  acc=65.2%  |  Val    loss=0.8219  acc=71.0%
#   Epoch 86/100  |  Train  loss=0.9698  acc=65.6%  |  Val    loss=0.8189  acc=70.8%
#   Epoch 87/100  |  Train  loss=0.9649  acc=65.5%  |  Val    loss=0.8109  acc=71.1%
#   Epoch 88/100  |  Train  loss=0.9697  acc=65.4%  |  Val    loss=0.8081  acc=71.5%
#   Epoch  89 [train]:  80%|████████  | 501/625 [00:06<00:01, 80.69it/s, acc=65.9%, loss=0.9574]

# %%
# 1.2  Adam + LeakyReLU — swap optimiser, keep everything else the same
from experiments.task01_cnn_adam_leakyrelu import main as run_adam_leakyrelu
run_adam_leakyrelu()

# %%
# 1.3  Adam + Tanh — swap activation function (this is the required separate file)
from experiments.task01_cnn_adam_tanh import main as run_adam_tanh
run_adam_tanh()

# %% [markdown]
# ---
# ## Section 2 — Task 0.2.1: AlexNet Transfer Learning on CIFAR-10
#
# AlexNet was pretrained on **ImageNet** (1,000 classes, 224×224 images).
# We adapt it for **CIFAR-10** (10 classes) two different ways:
#
# - **Fine-tuning** — all layers are updated → higher accuracy, more compute
# - **Feature extraction** — backbone is frozen, only the final layer trains → faster, slightly lower accuracy
#
# In both cases the original last layer `Linear(4096 → 1000)` is replaced with `Linear(4096 → 10)`.

# %%
# 2.1  AlexNet — Full Fine-Tuning (all layers updated)
from experiments.task02_alexnet_finetune import main as run_alexnet_finetune
run_alexnet_finetune()
# Out:
#   Epoch 24/100  |  Train  loss=0.0836  acc=97.2%  |  Val    loss=0.3195  acc=91.0%
#   Epoch 25/100  |  Train  loss=0.0816  acc=97.2%  |  Val    loss=0.3179  acc=91.0%
#   Epoch 26/100  |  Train  loss=0.0779  acc=97.4%  |  Val    loss=0.3348  acc=91.2%
#   Epoch 27/100  |  Train  loss=0.0762  acc=97.4%  |  Val    loss=0.3321  acc=91.0%
#   Epoch 28/100  |  Train  loss=0.0786  acc=97.3%  |  Val    loss=0.3237  acc=91.0%
#   Epoch 29/100  |  Train  loss=0.0712  acc=97.7%  |  Val    loss=0.3491  acc=90.6%
#   Epoch 30/100  |  Train  loss=0.0728  acc=97.6%  |  Val    loss=0.4097  acc=89.6%
#   Epoch 31/100  |  Train  loss=0.0698  acc=97.7%  |  Val    loss=0.3888  acc=90.1%
#   Epoch 32/100  |  Train  loss=0.0761  acc=97.6%  |  Val    loss=0.3280  acc=91.3%
#   Epoch 33/100  |  Train  loss=0.0676  acc=97.7%  |  Val    loss=0.3121  acc=91.6%
#   Epoch 34/100  |  Train  loss=0.0657  acc=97.8%  |  Val    loss=0.3524  acc=90.9%
#   Epoch 35/100  |  Train  loss=0.0687  acc=97.8%  |  Val    loss=0.3028  acc=91.5%
#   Epoch 36/100  |  Train  loss=0.0605  acc=98.0%  |  Val    loss=0.3978  acc=89.8%
#   Epoch 37/100  |  Train  loss=0.0638  acc=97.8%  |  Val    loss=0.3505  acc=90.9%
#   Epoch 38/100  |  Train  loss=0.0633  acc=98.0%  |  Val    loss=0.3645  acc=90.7%
#   Epoch 39/100  |  Train  loss=0.0639  acc=97.9%  |  Val    loss=0.3464  acc=91.2%
#   Epoch 40/100  |  Train  loss=0.0676  acc=97.9%  |  Val    loss=0.3738  acc=90.8%
#   Epoch 41/100  |  Train  loss=0.0625  acc=98.0%  |  Val    loss=0.3420  acc=91.5%
#   Epoch 42/100  |  Train  loss=0.0614  acc=98.0%  |  Val    loss=0.3580  acc=91.2%
#   Epoch 43/100  |  Train  loss=0.0594  acc=98.1%  |  Val    loss=0.3658  acc=91.0%
#   Epoch 44/100  |  Train  loss=0.0604  acc=98.0%  |  Val    loss=0.3616  acc=91.5%
#   Epoch 45/100  |  Train  loss=0.0610  acc=98.0%  |  Val    loss=0.3420  acc=91.7%
#   Epoch 46/100  |  Train  loss=0.0594  acc=98.2%  |  Val    loss=0.3626  acc=90.9%
#   Epoch 47/100  |  Train  loss=0.0583  acc=98.2%  |  Val    loss=0.3919  acc=91.3%
#   Epoch 48/100  |  Train  loss=0.0591  acc=98.1%  |  Val    loss=0.3690  acc=91.3%
#   Epoch 49/100  |  Train  loss=0.0565  acc=98.2%  |  Val    loss=0.3693  acc=90.8%
#   Epoch 50/100  |  Train  loss=0.0615  acc=98.1%  |  Val    loss=0.3987  acc=90.1%
#   Epoch 51/100  |  Train  loss=0.0602  acc=98.2%  |  Val    loss=0.3703  acc=91.0%
#   Epoch 52/100  |  Train  loss=0.0587  acc=98.2%  |  Val    loss=0.3816  acc=90.6%
#   Epoch 53/100  |  Train  loss=0.0573  acc=98.2%  |  Val    loss=0.4166  acc=91.0%
#   Epoch 54/100  |  Train  loss=0.0593  acc=98.2%  |  Val    loss=0.3737  acc=90.9%
#   Epoch 55/100  |  Train  loss=0.0591  acc=98.1%  |  Val    loss=0.4177  acc=90.2%
#   Epoch 56/100  |  Train  loss=0.0562  acc=98.3%  |  Val    loss=0.3581  acc=91.2%
#   Epoch 57/100  |  Train  loss=0.0571  acc=98.1%  |  Val    loss=0.3454  acc=91.1%
#   Epoch 58/100  |  Train  loss=0.0609  acc=98.2%  |  Val    loss=0.4092  acc=91.0%
#   Epoch 59/100  |  Train  loss=0.0545  acc=98.3%  |  Val    loss=0.4239  acc=90.2%
#   Epoch 60/100  |  Train  loss=0.0554  acc=98.3%  |  Val    loss=0.3760  acc=91.5%
#   Epoch 61/100  |  Train  loss=0.0604  acc=98.1%  |  Val    loss=0.3584  acc=91.1%
#   Epoch  62 [train]:  86%|████████▌ | 1071/1250 [00:39<00:06, 26.32it/s, acc=98.4%, loss=0.0530]

# %%
# 2.2  AlexNet — Feature Extraction (backbone frozen, only FC head trains)
from experiments.task02_alexnet_feature_extraction import main as run_alexnet_features
run_alexnet_features()

# %% [markdown]
# ---
# ## Section 3 — Task 0.2.2: Transfer Learning from MNIST → SVHN
#
# The cell below runs two stages automatically:
#
# **Stage 1** — Train a CNN from scratch on MNIST (clean handwritten digits, 28×28 grayscale).  Save the weights.
# **Stage 2** — Load those weights. Freeze the feature extractor. Fine-tune only the classifier on SVHN (real street-sign digits).
#
# SVHN images are converted to grayscale and resized to 28×28 so the **exact same architecture** works on both datasets.
#
# > **Grade-5 larger dataset**: set `"use_extra_data": True` in `config.py → SVHN_TRANSFER_CONFIG`
# > to also download the SVHN *extra* split (~531 K images, ~1 GB).

# %%
# 3.1  Stage 1: Train on MNIST  →  Stage 2: Transfer to SVHN
from experiments.task02_mnist_to_svhn import main as run_mnist_to_svhn
run_mnist_to_svhn()

# %% [markdown]
# ---
# ## Section 4 — Grade 5: Two Transformer Models on CIFAR-10
#
# Runs **ViT-B/16** and **Swin-T** back-to-back, both pretrained on ImageNet and fine-tuned for CIFAR-10.
#
# - **ViT-B/16** — splits image into 16×16 patches, applies global self-attention across all patches
# - **Swin-T** — uses local shifted-window attention in a hierarchical layout, more memory-efficient
#
# > ⚠ GPU strongly recommended. On CPU, reduce `"epochs"` in `config.py` (e.g. to `1`) to save time.

# %%
# 4.1  ViT-B/16 + Swin-T on CIFAR-10
from experiments.grade5_transformers_cifar10 import main as run_transformers
run_transformers()

# %% [markdown]
# ---
# ## Section 5 — Weights & Biases: View All Results
#
# All experiments automatically log to **https://wandb.ai** — no local server needed, no port forwarding required.
#
# ### First-time setup (run once)
# Run cell 17 below — it installs wandb (if missing) and logs you in with your API key.
# Get your key at: **https://wandb.ai/authorize**
#
# ### Viewing results
# Open **https://wandb.ai** in any browser — all runs are grouped under project **`advanced-ai-lab`**.
# Use the **Charts** panel to compare training curves from all experiments side-by-side.
#
# > To rename the project, change `WANDB_PROJECT` in `config.py`.

# %%
# 5.1  Log in to Weights & Biases (run once)
# This installs wandb if needed, then opens a login prompt.
# Paste your API key from https://wandb.ai/authorize when prompted.

import subprocess, sys

# Install wandb if not already present
subprocess.run([sys.executable, "-m", "pip", "install", "-q", "wandb"], check=True)
